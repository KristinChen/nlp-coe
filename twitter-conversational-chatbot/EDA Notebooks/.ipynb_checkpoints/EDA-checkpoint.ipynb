# %%
import numpy as np
import pandas as pd
import re
import nltk
import string
pd.options.mode.chained_assignment = None

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\JiatingChen\\Documents\\nlp-coe\\twitter-conversational-chatbot\\EDA Notebooks'

# %%
os.listdir('C:\\Users\\JiatingChen\\Documents\\archive\\twcs')
# Out:
# ['twcs.csv']

# %%
tweets = pd.read_csv("C:\\Users\\JiatingChen\\Documents\\archive\\twcs\\twcs.csv")

# %%
tweets["text"] = tweets["text"].astype(str)

# %%
tweets.shape #2,811,774
# Out:
# (2811774, 7)

# %%
tweets.sort_values('tweet_id').head(20)
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# 5               6  sprintcare    False  Tue Oct 31 21:46:24 +0000 2017
# 2314173         7      115712     True  Tue Oct 31 21:47:48 +0000 2017
# 6               8      115712     True  Tue Oct 31 21:45:10 +0000 2017
# 2314166         9  sprintcare    False  Tue Oct 31 21:46:14 +0000 2017
# 2314174        10  sprintcare    False  Tue Oct 31 21:45:59 +0000 2017
# 7              11  sprintcare    False  Tue Oct 31 22:10:35 +0000 2017
# 8              12      115713     True  Tue Oct 31 22:04:47 +0000 2017
# 48297          13  sprintcare    False  Wed Nov 01 20:48:14 +0000 2017
# 2375616        14  sprintcare    False  Wed Nov 01 20:47:40 +0000 2017
# 9              15  sprintcare    False  Tue Oct 31 20:03:31 +0000 2017
# 10             16      115713     True  Tue Oct 31 20:00:43 +0000 2017
# 11             17  sprintcare    False  Tue Oct 31 19:59:13 +0000 2017
# 12             18      115713     True  Tue Oct 31 19:56:01 +0000 2017
# 13             19  sprintcare    False  Tue Oct 31 22:10:10 +0000 2017
# 14             20      115715     True  Tue Oct 31 22:03:34 +0000 2017
#
#                                                       text response_tweet_id  \
# 0        @115712 I understand. I would like to assist y...                 2
# 1            @sprintcare and how do you propose we do that               NaN
# 2        @sprintcare I have sent several private messag...                 1
# 3        @115712 Please send us a Private Message so th...                 3
# 4                                       @sprintcare I did.                 4
# 5        @115712 Can you please send us a private messa...               5,7
# 2314173  @sprintcare the only way I can get a response ...               NaN
# 6                @sprintcare is the worst customer service            9,6,10
# 2314166  @115712 I would love the chance to review the ...               NaN
# 2314174  @115712 Hello! We never like our customers to ...               NaN
# 7        @115713 This is saddening to hear. Please shoo...               NaN
# 8        @sprintcare You gonna magically change your co...          11,13,14
# 48297    @115713 I would really like to work with you t...               NaN
# 2375616  @115713 Hi, my name is Shantel, I'm a resoluti...               NaN
# 9        @115713 We understand your concerns and we'd l...                12
# 10       @sprintcare Since I signed up with you....Sinc...                15
# 11       @115713 H there! We'd definitely like to work ...                16
# 12       @115714 y’all lie about your “great” connectio...                17
# 13       @115715 Please send me a private message so th...               NaN
# 14       @115714 whenever I contact customer support, t...                19
#
#          in_response_to_tweet_id
# 0                            3.0
# 1                            1.0
# 2                            4.0
# 3                            5.0
# 4                            6.0
# 5                            8.0
# 2314173                      6.0
# 6                            NaN
# 2314166                      8.0
# 2314174                      8.0
# 7                           12.0
# 8                           15.0
# 48297                       12.0
# 2375616                     12.0
# 9                           16.0
# 10                          17.0
# 11                          18.0
# 12                           NaN
# 13                          20.0
# 14                           NaN

# %%
# in_response_tweet_id = 1: tweet_id = 1 is the prior sentense
# response_tweet_id = 1: tweet_id = 1 is the next sentense

# %%
first_inbound = tweets[pd.isnull(tweets.in_response_to_tweet_id)] #initize the conversation
inbounds_and_outbounds = pd.merge(first_inbound, tweets, left_on='tweet_id', 
                                  right_on='in_response_to_tweet_id') 
inbounds_and_outbounds.sort_values(['tweet_id_x', 'created_at_y'], ascending= [True, True]).shape #895,514 back-and-forth dialog
# Out:
# (895514, 14)

# %%
inbounds_and_outbounds.head(100).created_at_y = pd.to_datetime(inbounds_and_outbounds.head(100).created_at_y)

# %%
inbounds_and_outbounds.head(100).sort_values(['tweet_id_x', 'created_at_y'], ascending= [True, True])
# Out:
#     tweet_id_x author_id_x  inbound_x                    created_at_x  \
# 2            8      115712       True  Tue Oct 31 21:45:10 +0000 2017
# 1            8      115712       True  Tue Oct 31 21:45:10 +0000 2017
# 0            8      115712       True  Tue Oct 31 21:45:10 +0000 2017
# 3           18      115713       True  Tue Oct 31 19:56:01 +0000 2017
# 4           20      115715       True  Tue Oct 31 22:03:34 +0000 2017
# ..         ...         ...        ...                             ...
# 95         320      115789       True  Tue Oct 31 21:17:16 +0000 2017
# 96         323      115791       True  Tue Oct 31 19:39:09 +0000 2017
# 97         325      115792       True  Wed Nov 22 08:55:35 +0000 2017
# 98         331      115795       True  Tue Oct 31 21:48:40 +0000 2017
# 99         348      115798       True  Mon Aug 29 03:20:05 +0000 2011
#
#                                                text_x  \
# 2           @sprintcare is the worst customer service
# 1           @sprintcare is the worst customer service
# 0           @sprintcare is the worst customer service
# 3   @115714 y’all lie about your “great” connectio...
# 4   @115714 whenever I contact customer support, t...
# ..                                                ...
# 95  @115790 @XboxSupport redeemed a code for fifa ...
# 96  @1520 @XboxSupport  the 5 app on Xboxes not wo...
# 97                           amazonプライムビデオ、再生エラーが多いです
# 98  Something going on at Preston train station ? ...
# 99  Lost your booking number? No worries, just dro...
#
#                                   response_tweet_id_x  \
# 2                                              9,6,10
# 1                                              9,6,10
# 0                                              9,6,10
# 3                                                  17
# 4                                                  19
# ..                                                ...
# 95                                                319
# 96                                                321
# 97                                                324
# 98                                                330
# 99  349,350,351,352,347,353,354,355,356,357,358,35...
#
#     in_response_to_tweet_id_x  tweet_id_y  author_id_y  inbound_y  \
# 2                         NaN          10   sprintcare      False
# 1                         NaN           9   sprintcare      False
# 0                         NaN           6   sprintcare      False
# 3                         NaN          17   sprintcare      False
# 4                         NaN          19   sprintcare      False
# ..                        ...         ...          ...        ...
# 95                        NaN         319  XboxSupport      False
# 96                        NaN         321  XboxSupport      False
# 97                        NaN         324   AmazonHelp      False
# 98                        NaN         330       115794       True
# 99                        NaN         347       115797       True
#
#                       created_at_y  \
# 2   Tue Oct 31 21:45:59 +0000 2017
# 1   Tue Oct 31 21:46:14 +0000 2017
# 0   Tue Oct 31 21:46:24 +0000 2017
# 3   Tue Oct 31 19:59:13 +0000 2017
# 4   Tue Oct 31 22:10:10 +0000 2017
# ..                             ...
# 95  Tue Oct 31 22:12:17 +0000 2017
# 96  Tue Oct 31 22:03:03 +0000 2017
# 97  Wed Nov 22 09:06:00 +0000 2017
# 98  Tue Oct 31 21:55:35 +0000 2017
# 99  Tue Oct 31 01:57:03 +0000 2017
#
#                                                text_y response_tweet_id_y  \
# 2   @115712 Hello! We never like our customers to ...                 NaN
# 1   @115712 I would love the chance to review the ...                 NaN
# 0   @115712 Can you please send us a private messa...                 5,7
# 3   @115713 H there! We'd definitely like to work ...                  16
# 4   @115715 Please send me a private message so th...                 NaN
# ..                                                ...                 ...
# 95  @115789 Hello! Would you mind following us and...                 NaN
# 96  @115791 Can you show us what is appearing on y...                 322
# 97  @115792 ご不便をおかけしております。アプリをご利用でしょうか。強制停止&gt;端末の...                 NaN
# 98                @115795 @115796 What have you seen?                 329
# 99  @AirAsiaSupport lost my booking # chua loreen ...                 343
#
#     in_response_to_tweet_id_y
# 2                         8.0
# 1                         8.0
# 0                         8.0
# 3                        18.0
# 4                        20.0
# ..                        ...
# 95                      320.0
# 96                      323.0
# 97                      325.0
# 98                      331.0
# 99                      348.0
#
# [100 rows x 14 columns]

# %%
inbounds_and_outbounds.head(100).sort_values(['tweet_id_x', 'created_at_y'], ascending= [True, True])[['text_x', 'text_y']].head(100).to_csv('conv.txt', index = False)

# %%
inbounds_and_outbounds.head()

# %%
inbounds_and_outbounds[['text_x', 'text_y']].head(100).to_csv('conv.txt')

# %%
first_inbound2 = tweets[pd.isnull(tweets.in_response_to_tweet_id) & tweets.inbound]
inbounds_and_outbounds = pd.merge(first_inbound2, tweets, left_on='tweet_id', 
                                  right_on='in_response_to_tweet_id') #.sample(frac=1)
inbounds_and_outbounds2 = inbounds_and_outbounds[inbounds_and_outbounds.inbound_y ^ True]
inbounds_and_outbounds2.sort_values('tweet_id_x').shape #794,299 back-and-forth dialog responded from companies

# %% [markdown]
# ## citation: https://www.kaggle.com/soaxelbrooke/twitter-basic-seq2seq
# ## next step 1 - text preprocessing
# - Lower casing
# - Removal of Punctuations
# - Removal of Stopwords
# - Removal of Frequent words
# - Removal of Rare words
# - Stemming
# - Lemmatization
# - Removal of emojis
# - Removal of emoticons
# - Conversion of emoticons to words
# - Conversion of emojis to words
# - Removal of URLs
# - Removal of HTML tags
# - Chat words conversion
# - Spelling correction
#
# ## next step 2 - build virtualenv for all necessary packages
