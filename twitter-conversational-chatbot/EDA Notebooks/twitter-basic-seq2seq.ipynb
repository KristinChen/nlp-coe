# %%
import re
import random
import time

print('Library versions:')

import keras
print(f'keras:{keras.__version__}')
import pandas as pd
print(f'pandas:{pd.__version__}')
import sklearn
print(f'sklearn:{sklearn.__version__}')
import nltk
print(f'nltk:{nltk.__version__}')
import numpy as np
print(f'numpy:{np.__version__}')

from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import casual_tokenize
# Out:
# Library versions:
# Using TensorFlow backend.
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# keras:2.3.1
# pandas:1.3.4
# sklearn:1.0.2
# nltk:3.6.7
# numpy:1.21.5

# %%
# from tqdm import tqdm.notebook as tqdm # Special jupyter notebook progress bar 💫
from tqdm.notebook import tqdm as tqdm

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\JiatingChen\\Documents\\nlp-coe\\twitter-conversational-chatbot\\EDA Notebooks'

# %% [markdown]
# ## Model Parameters

# %%
# 8192 - large enough for demonstration, larger values make network training slower
MAX_VOCAB_SIZE = 2**13
# seq2seq generally relies on fixed length message vectors - longer messages provide more info
# but result in slower training and larger networks
MAX_MESSAGE_LEN = 30  
# Embedding size for words - gives a trade off between expressivity of words and network size
EMBEDDING_SIZE = 100
# Embedding size for whole messages, same trade off as word embeddings
CONTEXT_SIZE = 100
# Larger batch sizes generally reach the average response faster, but small batch sizes are
# required for the model to learn nuanced responses.  Also, GPU memory limits max batch size.
BATCH_SIZE = 4
# Helps regularize network and prevent overfitting.
DROPOUT = 0.2
# High learning rate helps model reach average response faster, but can make it hard to 
# converge on nuanced responses
LEARNING_RATE=0.005

# Tokens needed for seq2seq
UNK = 0  # words that aren't found in the vocab
PAD = 1  # after message has finished, this fills all remaining vector positions
START = 2  # provided to the model at position 0 for every response predicted

# Implementaiton detail for allowing this to be run in Kaggle's notebook hardware
SUB_BATCH_SIZE = 1000

# %% [markdown]
# ## Data Prep
# Here, we'll prepare the data for training our seq2seq model, including:
#
# - Replace screen names with `@__sn__` token to show model the commonality between them
# - Build a vocab to turn tokens into integers suitable for our seq2seq model
# - Tokenize input and target text into fixed size vectors
# - Partition our dataset into train and test sets

# %% [markdown]
# ### Data Loading and Reshaping
# Pulled from [this kernel](https://www.kaggle.com/soaxelbrooke/first-inbound-and-response-tweets).

# %%
""" A kernel posted on Kaggle that shows how to pull just the first consumer request and
    company response from the dataset.
"""

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

tweets = pd.read_csv('../data/twcs/twcs.csv')


# Pick only inbound tweets that aren't in reply to anything...
first_inbound = tweets[pd.isnull(tweets.in_response_to_tweet_id) & tweets.inbound]
print('Found {} first inbound messages.'.format(len(first_inbound)))

# Merge in all tweets in response
inbounds_and_outbounds = pd.merge(first_inbound, tweets, left_on='tweet_id', 
                                  right_on='in_response_to_tweet_id')
print("Found {} responses.".format(len(inbounds_and_outbounds)))

# Filter out cases where reply tweet isn't from company
inbounds_and_outbounds = inbounds_and_outbounds[inbounds_and_outbounds.inbound_y ^ True]

# Et voila!
print("Found {} responses from companies.".format(len(inbounds_and_outbounds)))
print("Tweets Preview:")
print(inbounds_and_outbounds)
# Out:
# Found 787346 first inbound messages.
# Found 875292 responses.
# Found 794299 responses from companies.
# Tweets Preview:
#         tweet_id_x author_id_x  inbound_x                    created_at_x  \
# 0                8      115712       True  Tue Oct 31 21:45:10 +0000 2017
# 1                8      115712       True  Tue Oct 31 21:45:10 +0000 2017
# 2                8      115712       True  Tue Oct 31 21:45:10 +0000 2017
# 3               18      115713       True  Tue Oct 31 19:56:01 +0000 2017
# 4               20      115715       True  Tue Oct 31 22:03:34 +0000 2017
# ...            ...         ...        ...                             ...
# 875287     2987942      823867       True  Wed Nov 22 07:30:39 +0000 2017
# 875288     2987944      823868       True  Wed Nov 22 07:43:36 +0000 2017
# 875289     2987946      524544       True  Wed Nov 22 08:25:48 +0000 2017
# 875290     2987948      823869       True  Wed Nov 22 08:35:16 +0000 2017
# 875291     2987950      823870       True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                    text_x response_tweet_id_x  \
# 0               @sprintcare is the worst customer service              9,6,10
# 1               @sprintcare is the worst customer service              9,6,10
# 2               @sprintcare is the worst customer service              9,6,10
# 3       @115714 y’all lie about your “great” connectio...                  17
# 4       @115714 whenever I contact customer support, t...                  19
# ...                                                   ...                 ...
# 875287  Hai @AirAsiaSupport #asking how many days need...             2987941
# 875288  @AirAsiaSupport \n\nI am unable to do web chec...             2987943
# 875289  @VirginTrains Hope you are well? Does the 9.30...             2987945
# 875290  @115714 wtf!? I’ve been having really shitty s...             2987947
# 875291  @AldiUK  warm sloe gin mince pies with ice cre...     2987951,2987949
#
#         in_response_to_tweet_id_x  tweet_id_y     author_id_y  inbound_y  \
# 0                             NaN           6      sprintcare      False
# 1                             NaN           9      sprintcare      False
# 2                             NaN          10      sprintcare      False
# 3                             NaN          17      sprintcare      False
# 4                             NaN          19      sprintcare      False
# ...                           ...         ...             ...        ...
# 875287                        NaN     2987941  AirAsiaSupport      False
# 875288                        NaN     2987943  AirAsiaSupport      False
# 875289                        NaN     2987945    VirginTrains      False
# 875290                        NaN     2987947      sprintcare      False
# 875291                        NaN     2987949          AldiUK      False
#
#                           created_at_y  \
# 0       Tue Oct 31 21:46:24 +0000 2017
# 1       Tue Oct 31 21:46:14 +0000 2017
# 2       Tue Oct 31 21:45:59 +0000 2017
# 3       Tue Oct 31 19:59:13 +0000 2017
# 4       Tue Oct 31 22:10:10 +0000 2017
# ...                                ...
# 875287  Wed Nov 22 07:55:05 +0000 2017
# 875288  Wed Nov 22 07:54:57 +0000 2017
# 875289  Wed Nov 22 08:27:34 +0000 2017
# 875290  Wed Nov 22 08:43:51 +0000 2017
# 875291  Wed Nov 22 08:31:24 +0000 2017
#
#                                                    text_y response_tweet_id_y  \
# 0       @115712 Can you please send us a private messa...                 5,7
# 1       @115712 I would love the chance to review the ...                 NaN
# 2       @115712 Hello! We never like our customers to ...                 NaN
# 3       @115713 H there! We'd definitely like to work ...                  16
# 4       @115715 Please send me a private message so th...                 NaN
# ...                                                   ...                 ...
# 875287     @823867 we have replied you via DM.Thanks-Emir                 NaN
# 875288  @823868 Sorry but kindly try to clear browser,...                 NaN
# 875289  @524544 That's a Peak service. The 09:56 is th...                 NaN
# 875290  @823869 Hey, we'd be happy to look into this f...                 NaN
# 875291  @823870 Sounds delicious, Sarah! 😋 https://t.c...                 NaN
#
#         in_response_to_tweet_id_y
# 0                             8.0
# 1                             8.0
# 2                             8.0
# 3                            18.0
# 4                            20.0
# ...                           ...
# 875287                  2987942.0
# 875288                  2987944.0
# 875289                  2987946.0
# 875290                  2987948.0
# 875291                  2987950.0
#
# [794299 rows x 14 columns]

# %%
tweets.head() 
#inbound: message from others (response_tweet_id); outbound: message sent by the tweet_id (in_response_to_tweet_id)
# Out:
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
# 1      @sprintcare and how do you propose we do that               NaN
# 2  @sprintcare I have sent several private messag...                 1
# 3  @115712 Please send us a Private Message so th...                 3
# 4                                 @sprintcare I did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# 4                      6.0

# %%
# %%time
tweets = pd.read_csv('../data/twcs/twcs.csv')

first_inbound = tweets[pd.isnull(tweets.in_response_to_tweet_id) & tweets.inbound]

inbounds_and_outbounds = pd.merge(first_inbound, tweets, left_on='tweet_id', 
                                  right_on='in_response_to_tweet_id').sample(frac=1)

# Filter to only outbound replies (from companies)
inbounds_and_outbounds = inbounds_and_outbounds[inbounds_and_outbounds.inbound_y ^ True]

#tqdm().pandas()  # Enable tracking of progress in dataframe `apply` calls
# Out:
# Wall time: 11.3 s

# %%
tqdm().pandas()
# Out:
# 0it [00:00, ?it/s]

# %%
print(f'Data shape: {inbounds_and_outbounds.shape}')
# Out:
# Data shape: (794299, 14)

# %% [markdown]
# ### Tokenizing and Vocab Build
#
# We'll use NLTK's `casual_tokenize`, which handles a lot of corner cases found in social media data ("casual" text data) along with scitkit learn's `CountVectorizer`.  We won't use the actual `CountVectorizer`, just use it as a convenient vocabulary builder, which we'll apply with functions that turn text into "word indexes" - integers that represent each word - and back.

# %%
inbounds_and_outbounds.head()
# Out:
#         tweet_id_x author_id_x  inbound_x                    created_at_x  \
# 514330     1834275      550194       True  Tue Oct 17 19:32:31 +0000 2017
# 86976       332623      195209       True  Sat Oct 07 14:11:32 +0000 2017
# 160341      598547      261930       True  Sun Dec 03 13:30:52 +0000 2017
# 224425      830319      317722       True  Wed Oct 11 00:33:35 +0000 2017
# 860406     2941537      812757       True  Wed Nov 29 12:11:36 +0000 2017
#
#                                                    text_x response_tweet_id_x  \
# 514330  @british_airways - flight to Seattle, flight w...     1834274,1834276
# 86976   Wheres my achievement @115790 @XboxSupport htt...              332621
# 160341  @Tesco this drink is falsely advertised. This ...              598545
# 224425  Still pissed about the #huluupdate @hulu_suppo...              830318
# 860406  @140046 Any idea where I can buy your #glutenf...     2941536,2941538
#
#         in_response_to_tweet_id_x  tweet_id_y      author_id_y  inbound_y  \
# 514330                        NaN     1834274  British_Airways      False
# 86976                         NaN      332621      XboxSupport      False
# 160341                        NaN      598545            Tesco      False
# 224425                        NaN      830318     hulu_support      False
# 860406                        NaN     2941538       sainsburys      False
#
#                           created_at_y  \
# 514330  Wed Oct 18 05:46:31 +0000 2017
# 86976   Sat Oct 07 19:04:26 +0000 2017
# 160341  Sun Dec 03 20:22:29 +0000 2017
# 224425  Fri Oct 13 03:41:39 +0000 2017
# 860406  Wed Nov 29 14:41:45 +0000 2017
#
#                                                    text_y response_tweet_id_y  \
# 514330  @550194 If you want us to take a look, please ...                 NaN
# 86976   @195209 Hi there! Could you follow the steps h...              332622
# 160341  @261930 Hi Laszlo, I'd be happy to look in to ...              598546
# 224425  @317722 Rest assured we're making updates base...                 NaN
# 860406  @812757 Hi Michelle, you can place a product r...                 NaN
#
#         in_response_to_tweet_id_y
# 514330                  1834275.0
# 86976                    332623.0
# 160341                   598547.0
# 224425                   830319.0
# 860406                  2941537.0

# %%
inbounds_and_outbounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 794299 entries, 514330 to 392195
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   tweet_id_x                 794299 non-null  int64
#  1   author_id_x                794299 non-null  object
#  2   inbound_x                  794299 non-null  bool
#  3   created_at_x               794299 non-null  object
#  4   text_x                     794299 non-null  object
#  5   response_tweet_id_x        794299 non-null  object
#  6   in_response_to_tweet_id_x  0 non-null       float64
#  7   tweet_id_y                 794299 non-null  int64
#  8   author_id_y                794299 non-null  object
#  9   inbound_y                  794299 non-null  bool
#  10  created_at_y               794299 non-null  object
#  11  text_y                     794299 non-null  object
#  12  response_tweet_id_y        263771 non-null  object
#  13  in_response_to_tweet_id_y  794299 non-null  float64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 80.3+ MB

# %%
inbounds_and_outbounds.author_id_y.value_counts(normalize = True).head(20)
# Out:
# AmazonHelp         0.106556
# AppleSupport       0.093960
# Uber_Support       0.050395
# Delta              0.035862
# SpotifyCares       0.033917
# Tesco              0.031332
# AmericanAir        0.030852
# comcastcares       0.030015
# SouthwestAir       0.026421
# TMobileHelp        0.025261
# British_Airways    0.024690
# Ask_Spectrum       0.021742
# VirginTrains       0.018075
# UPSHelp            0.017994
# hulu_support       0.017870
# ChipotleTweets     0.017441
# sprintcare         0.015925
# XboxSupport        0.015748
# AskPlayStation     0.014349
# sainsburys         0.013550
# Name: author_id_y, dtype: float64

# %%
inbounds_and_outbounds.author_id_y.value_counts(normalize = True).tail(20) #108 companies
# Out:
# askvisa            0.000721
# ask_progressive    0.000658
# GooglePlayMusic    0.000643
# YahooCare          0.000640
# USCellularCares    0.000628
# asksalesforce      0.000578
# MTNC_Care          0.000574
# MOO                0.000524
# KeyBank_Help       0.000482
# AskSeagate         0.000473
# AskVirginMoney     0.000466
# OPPOCareIN         0.000428
# AskRobinhood       0.000392
# AskTigogh          0.000349
# JackBox            0.000253
# mediatemplehelp    0.000239
# AskDSC             0.000238
# CarlsJr            0.000174
# HotelTonightCX     0.000165
# OfficeSupport      0.000073
# Name: author_id_y, dtype: float64

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
# Replace anonymized screen names with common token @__sn__
def sn_replace(match):
    _sn = match.group(2).lower()
    if not _sn.isnumeric():
        # This is a company screen name
        return match.group(1) + match.group(2)
    return ' @__sn__'

sn_re = re.compile('(\W@|^@)([a-zA-Z0-9_]+)')
print("Replacing anonymized screen names in X...")
x_text = inbounds_and_outbounds.text_x.progress_apply(lambda txt: sn_re.sub(sn_replace, txt))
print("Replacing anonymized screen names in Y...")
y_text = inbounds_and_outbounds.text_y.progress_apply(lambda txt: sn_re.sub(sn_replace, txt))
# Out:
# Replacing anonymized screen names in X...
#   0%|          | 0/794299 [00:00<?, ?it/s]
# Replacing anonymized screen names in Y...
#   0%|          | 0/794299 [00:00<?, ?it/s]

# %%
def sn_replace(match):
    _sn = match.group(2).lower()
    if not _sn.isnumeric():
        # This is a company screen name
        return match.group(1) + match.group(2)
    return ' @__sn__'
inbounds_and_outbounds.text_x[0:10]
# Out:
# 514330    @british_airways - flight to Seattle, flight w...
# 86976     Wheres my achievement @115790 @XboxSupport htt...
# 160341    @Tesco this drink is falsely advertised. This ...
# 224425    Still pissed about the #huluupdate @hulu_suppo...
# 860406    @140046 Any idea where I can buy your #glutenf...
# 858257    @AmazonHelp Hi, is Amazon Household available ...
# 518640    @115858 please fix the issue with messages not...
# 508857                    Chase bank can suck my ass foreal
# 742272    And suddenly @115911 cuts out and I lose servi...
# 494175    Hey @Ask_Spectrum are you in contract disputes...
# Name: text_x, dtype: object

# %%
inbounds_and_outbounds.text_x[0:10].apply(lambda txt: sn_re.sub(sn_replace, txt))
# Out:
# 514330    @british_airways - flight to Seattle, flight w...
# 86976     Wheres my achievement @__sn__ @XboxSupport htt...
# 160341    @Tesco this drink is falsely advertised. This ...
# 224425    Still pissed about the #huluupdate @hulu_suppo...
# 860406     @__sn__ Any idea where I can buy your #gluten...
# 858257    @AmazonHelp Hi, is Amazon Household available ...
# 518640     @__sn__ please fix the issue with messages no...
# 508857                    Chase bank can suck my ass foreal
# 742272    And suddenly @__sn__ cuts out and I lose servi...
# 494175    Hey @Ask_Spectrum are you in contract disputes...
# Name: text_x, dtype: object

# %%
count_vec = CountVectorizer(tokenizer=casual_tokenize, max_features=MAX_VOCAB_SIZE - 3)
print("Fitting CountVectorizer on X and Y text data...")
count_vec.fit(tqdm(x_text + y_text))
analyzer = count_vec.build_analyzer()
vocab = {k: v + 3 for k, v in count_vec.vocabulary_.items()}
vocab['__unk__'] = UNK
vocab['__pad__'] = PAD
vocab['__start__'] = START

# Used to turn seq2seq predictions into human readable strings
reverse_vocab = {v: k for k, v in vocab.items()}
print(f"Learned vocab of {len(vocab)} items.")
# Out:
# Fitting CountVectorizer on X and Y text data...
#   0%|          | 0/794299 [00:00<?, ?it/s]
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   "The parameter 'token_pattern' will not be used"
# Learned vocab of 8192 items.

# %%
x_text + y_text
# Out:
# 514330    @british_airways - flight to Seattle, flight w...
# 86976     Wheres my achievement @__sn__ @XboxSupport htt...
# 160341    @Tesco this drink is falsely advertised. This ...
# 224425    Still pissed about the #huluupdate @hulu_suppo...
# 860406     @__sn__ Any idea where I can buy your #gluten...
#                                 ...
# 495943    @TMobileHelp Switched from Sprint less than 6 ...
# 85035      @__sn__ @idea_cares https://t.co/p9bYulAVYR @...
# 573101     @__sn__  please do something about this I️ no...
# 542974    @Ask_Spectrum A man can't even play xbox. We a...
# 392195    @Uber_Support You guys couldn't help me find m...
# Length: 794299, dtype: object

# %%
vocab['__start__']
# Out:
# 2

# %% [markdown]
# ### Vocab Helper Functions
# These helper functions take strings and turn them into word indexes used by the actual seq2seq models.  This turns something like "This is how we do it." into a padded array of integers, like [153, 4, 643, 48, 94, 54, 8, 0, 0, 0].  We'll apply the `to_word_idx` function to our text data to get our `N x MESSAGE_LEN` training/test data.

# %%
def to_word_idx(sentence):
    full_length = [vocab.get(tok, UNK) for tok in analyzer(sentence)] + [PAD] * MAX_MESSAGE_LEN
    return full_length[:MAX_MESSAGE_LEN]

def from_word_idx(word_idxs):
    return ' '.join(reverse_vocab[idx] for idx in word_idxs if idx != PAD).strip()

# %%
x_text.head().apply(to_word_idx)
# Out:
# 514330    [484, 155, 2992, 7207, 6330, 154, 2992, 7656, ...
# 86976     [7738, 4876, 602, 449, 543, 0, 1, 1, 1, 1, 1, ...
# 160341    [530, 7116, 2489, 3976, 0, 661, 157, 7116, 397...
# 224425    [6783, 5424, 568, 7088, 0, 501, 4354, 7496, 42...
# 860406    [449, 875, 3777, 7736, 3763, 1490, 1445, 7916,...
# Name: text_x, dtype: object

# %%
# Make sure our helpers work as expected...
x_text.head().apply(to_word_idx).apply(from_word_idx)
# Out:
# 514330    @british_airways - flight to seattle , flight ...
# 86976     wheres my achievement @__sn__ @xboxsupport __u...
# 160341    @tesco this drink is __unk__ advertised . this...
# 224425    still pissed about the __unk__ @hulu_support l...
# 860406    @__sn__ any idea where i can buy your #glutenf...
# Name: text_x, dtype: object

# %%
vocab['anyone']
# Out:
# 878

# %%
reverse_vocab[878]
# Out:
# 'anyone'

# %%
print("Calculating word indexes for X...")
x = pd.np.vstack(x_text.progress_apply(to_word_idx).values)
print("Calculating word indexes for Y...")
y = pd.np.vstack(y_text.progress_apply(to_word_idx).values)
# Out:
# Calculating word indexes for X...
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   0%|          | 0/794299 [00:00<?, ?it/s]
# Calculating word indexes for Y...
# C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   after removing the cwd from sys.path.
#   0%|          | 0/794299 [00:00<?, ?it/s]

# %% [markdown]
# ### Train / Test Split
# Here, we split our data into training and test sets.  For simplicity, we use a random split, which may result in different distributions between the training and test set, but we won't worry about that for this case.

# %%
all_idx = list(range(len(x)))
random.seed(1234)
train_idx = set(random.sample(all_idx, int(0.8 * len(all_idx))))
test_idx = {idx for idx in all_idx if idx not in train_idx}

train_x = x[list(train_idx)]
test_x = x[list(test_idx)]
train_y = y[list(train_idx)]
test_y = y[list(test_idx)]

assert train_x.shape == train_y.shape
assert test_x.shape == test_y.shape

print(f'Training data of shape {train_x.shape} and test data of shape {test_x.shape}.')
# Out:
# Training data of shape (635439, 30) and test data of shape (158860, 30).

# %%
train_x
# Out:
# array([[ 484,  155, 2992, ...,    1,    1,    1],
#        [7738, 4876,  602, ...,    1,    1,    1],
#        [ 530, 7116, 2489, ..., 2489,    4,  157],
#        ...,
#        [ 532, 6937, 3089, ...,    1,    1,    1],
#        [ 461,  552, 4583, ...,    1,    1,    1],
#        [ 534, 7909, 3310, ..., 2494, 2221,  157]])

# %% [markdown]
# ## Model Creation
# We'll create and compile the model here.  It will consist of the following components:
#
# - Shared word embeddings
#   - A shared embedding layer that turns word indexes (a sparse representation) into a dense/compressed representation.  This embeds both the request from the customer, and also the last words uttered by the model that are fed back into the model.
# - Encoder RNN
#   - In this case, a single LSTM layer.  This encodes the whole input sentence into a context vector (or thought vector) that represents completely what the customer is saying, and produces a single output.
# - Decoder RNN
#   - This RNN (also an LSTM in this case) decodes the context vector into a string of tokens/utterances.  For each time step, it takes the context vector and the embedded last utterance and produces the next utterance, which is fed back into the model.  More complex and effective models copy the encoder state into the decoder, add more layers of LSTMs, and apply attention mechanisms - but these are out of the scope of this simple example.
# - Next Word Dense+Softmax
#   - These two layers take the decoder output and turn it into the next word to be uttered.  The dense layer allows the decoder to not map directly to words uttered, and the softmax turns the dense layer output into a probability distribution, from which we pick the most likely next word.
#
# ![seq2seq model structure](https://i.imgur.com/JmuryKu.png)

# %%
# keras imports, because there are like... A million of them.
from keras.models import Model
# from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, Input, LSTM, Dropout, Embedding, RepeatVector, concatenate, \
    TimeDistributed
from keras.utils import np_utils

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.14.0'

# %%
import numpy as np
np.__version__
# Out:
# '1.21.5'

# %%
def create_model():
    shared_embedding = Embedding(
        output_dim=EMBEDDING_SIZE,
        input_dim=MAX_VOCAB_SIZE,
        input_length=MAX_MESSAGE_LEN,
        name='embedding',
    )
    
    # ENCODER
    
    encoder_input = Input(
        shape=(MAX_MESSAGE_LEN,),
        dtype='int32',
        name='encoder_input',
    )
    
    embedded_input = shared_embedding(encoder_input)
    
    # No return_sequences - since the encoder here only produces a single value for the
    # input sequence provided.
    encoder_rnn = LSTM(
        CONTEXT_SIZE,
        name='encoder',
        dropout=DROPOUT
    )
    
    context = RepeatVector(MAX_MESSAGE_LEN)(encoder_rnn(embedded_input))
    
    # DECODER
    
    last_word_input = Input(
        shape=(MAX_MESSAGE_LEN, ),
        dtype='int32',
        name='last_word_input',
    )
    
    embedded_last_word = shared_embedding(last_word_input)
    # Combines the context produced by the encoder and the last word uttered as inputs
    # to the decoder.
    decoder_input = concatenate([embedded_last_word, context], axis=2)
    
    # return_sequences causes LSTM to produce one output per timestep instead of one at the
    # end of the intput, which is important for sequence producing models.
    decoder_rnn = LSTM(
        CONTEXT_SIZE,
        name='decoder',
        return_sequences=True,
        dropout=DROPOUT
    )
    
    decoder_output = decoder_rnn(decoder_input)
    
    # TimeDistributed allows the dense layer to be applied to each decoder output per timestep
    next_word_dense = TimeDistributed(
        Dense(int(MAX_VOCAB_SIZE / 2), activation='relu'),
        name='next_word_dense',
    )(decoder_output)
    
    next_word = TimeDistributed(
        Dense(MAX_VOCAB_SIZE, activation='softmax'),
        name='next_word_softmax'
    )(next_word_dense)
    
    return Model(inputs=[encoder_input, last_word_input], outputs=[next_word])

s2s_model = create_model()
optimizer = Adam(lr=LEARNING_RATE, clipvalue=5.0)
s2s_model.compile(optimizer='adam', loss='categorical_crossentropy')

# %% [markdown]
# ## Model Training
# We'll train the model here.  After each sub-batch of the dataset, we'll test with static input strings to see how the model is progressing in human readable terms.  Its important to have these tests along with traditional model evaluation to provide a better understanding of how well the model is training.
#
# It's important to pull test strings from the real distribution of the data, also.  It can be hard to really put yourself in customers' shoes when writing test messages, and you will get non-representative results when you provide test examples that don't fit the true distribution of the input data (when your input text doesn't sound like real customer requests).

# %%
def add_start_token(y_array):
    """ Adds the start token to vectors.  Used for training data. """
    return np.hstack([
        START * np.ones((len(y_array), 1)),
        y_array[:, :-1],
    ])

def binarize_labels(labels):
    """ Helper function that turns integer word indexes into sparse binary matrices for 
        the expected model output.
    """
    return np.array([np_utils.to_categorical(row, num_classes=MAX_VOCAB_SIZE)
                     for row in labels])

# %%
def respond_to(model, text):
    """ Helper function that takes a text input and provides a text output. """
    input_y = add_start_token(PAD * np.ones((1, MAX_MESSAGE_LEN)))
    idxs = np.array(to_word_idx(text)).reshape((1, MAX_MESSAGE_LEN))
    for position in range(MAX_MESSAGE_LEN - 1):
        prediction = model.predict([idxs, input_y]).argmax(axis=2)[0]
        input_y[:,position + 1] = prediction[position]
    return from_word_idx(model.predict([idxs, input_y]).argmax(axis=2)[0])

# %%
def train_mini_epoch(model, start_idx, end_idx):
    """ Batching seems necessary in Kaggle Jupyter Notebook environments, since
        `model.fit` seems to freeze on larger batches (somewhere 1k-10k).
    """
    b_train_y = binarize_labels(train_y[start_idx:end_idx])
    input_train_y = add_start_token(train_y[start_idx:end_idx])
    
    model.fit(
        [train_x[start_idx:end_idx], input_train_y], 
        b_train_y,
        epochs=1,
        batch_size=BATCH_SIZE,
    )
    
    rand_idx = random.sample(list(range(len(test_x))), SUB_BATCH_SIZE)
    print('Test results:', model.evaluate(
        [test_x[rand_idx], add_start_token(test_y[rand_idx])],
        binarize_labels(test_y[rand_idx])
    ))
    
    input_strings = [
        "@AppleSupport I fix I this I stupid I problem I",
        "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service.",
    ]
    
    for input_string in input_strings:
        output_string = respond_to(model, input_string)
        print(f'> "{input_string}"\n< "{output_string}"')

# %% [markdown]
# ### Train the model!
#
# You can stop training by pressing the stop button - the training code is configured to watch for the `KeyboardInterrupt` exception triggered that way.  Also, it will run until the configured stopping point below.
#
#
# Let's start the training! 🚀

# %%
training_time_limit = 360 * 60  # seconds (notebooks terminate after 1 hour)
start_time = time.time()
stop_after = start_time + training_time_limit

class TimesUpInterrupt(Exception):
    pass

try:
    for epoch in range(100):
        print(f'Training in epoch {epoch}...')
        for start_idx in range(0, len(train_x), SUB_BATCH_SIZE):
            train_mini_epoch(s2s_model, start_idx, start_idx + SUB_BATCH_SIZE)
            if time.time() > stop_after:
                raise TimesUpInterrupt
except KeyboardInterrupt:
    print("Halting training from keyboard interrupt.")
except TimesUpInterrupt:
    print(f"Halting after {time.time() - start_time} seconds spent training.")
# Out:
# Training in epoch 0...
# WARNING:tensorflow:From C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\JiatingChen\anaconda3\envs\tf_test\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/1
# 1000/1000 [==============================] - 100s 100ms/step - loss: 4.7484
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 4.258560516357422
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ to , . to . ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ to , . to . ."
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 4.0111
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 3.863120491027832
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we can help ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ we can help ."
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 3.6510
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 3.6045391426086426
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , , we can help . please dm us a dm with your account number . ^ __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , , we can help . please dm us a dm with your account number . ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 3.4980
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 3.3517769260406496
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we can help . please dm us a dm with your account number so we can look into this ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we can help . please dm us a dm with your account number so we can look into this ."
# Epoch 1/1
# 1000/1000 [==============================] - 100s 100ms/step - loss: 3.3551
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 3.2765133666992186
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we want to hear this . please dm us a dm with your email address and we'll look into this ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we want to hear this . please dm us a dm with your email address and we'll look into this ."
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 3.1635
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 3.122022487640381
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , __unk__ . please dm us your email address and we'll take a look backstage"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , __unk__ . please dm us your email address and we'll take a look backstage"
# Epoch 1/1
# 1000/1000 [==============================] - 100s 100ms/step - loss: 3.0677
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 3.121109188079834
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we can help you please dm me your account number , and we'll be happy to look into this for you . ^ __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we can help you please dm me your account number , and we'll be happy to look into this for you . ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 3.0174
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.999117401123047
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we want to help . please send us a note here ; __unk__ so we can help ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we want to help . please send us a note here ; __unk__ so we can help ."
# Epoch 1/1
# 1000/1000 [==============================] - 100s 100ms/step - loss: 2.9624
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.9277359580993654
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we can help . please dm us with your account number so we can look into this for you ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we can help . please dm us with your account number so we can look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 100s 100ms/step - loss: 2.9275
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.9065203800201416
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we can help with your feedback . ^ __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we can help with your feedback . ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 2.9030
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.8455878868103026
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are sorry to hear this , please dm us your account number so we can look into this for you . ^ __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this , please dm us your account number so we can look into this for you . ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 100s 100ms/step - loss: 2.8564
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.8211562824249268
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we can help you with your feedback . please dm us your account's email address or username ? we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we can help you with your feedback . please dm us your account's email address or username ? we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 2.8014
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.8595116653442383
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are currently able to help . please dm us your full name and address and email address ? we'll take a look backstage / __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are currently able to help . please dm us your full name and address and email address ? we'll take a look backstage / __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 2.8546
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.8340239181518556
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! please send us a dm with your email address so we can connect ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! please send us a dm with your email address so we can connect ."
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 2.7630
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.6538987770080564
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! please dm us your account number , and address , and we will be able to help . ^ __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! please dm us your account number , and address , and we will be able to help . ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.7654
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.7146755867004395
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your account number so we can look into this for you ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your account number so we can look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.7750
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.6892468223571777
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , please send us a dm with your email address so we can connect ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , please send us a dm with your email address so we can connect ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.6765
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.696384229660034
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , i am sorry to hear this . please dm us with your email address so we can look into this . thanks . ^ __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , i am sorry to hear this . please dm us with your email address so we can look into this . thanks . ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.7095
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.6073607082366945
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we want to help with your order . please dm your full name , address , and address , and we will be happy to help"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we want to help with your order . please dm your full name , address , and address , and we will be happy to help"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.6426
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.6240529670715333
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! can you dm us your account's username or username or email address ? we'll take a look under this issue . - __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! can you dm us your account's username or username or email address ? we'll take a look under this issue . - __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.6126
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.6000152339935303
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! please dm us your email address so we can look into this for you . ^ __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! please dm us your email address so we can look into this for you . ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.6139
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.5407205085754394
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us with your email address and we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us with your email address and we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.5887
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.512290554046631
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear about this . please dm us your full name , address , and phone number so we can look into this"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear about this . please dm us your full name , address , and phone number so we can look into this"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.5952
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.582135368347168
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . can you dm us your account's username or email address ? we'll take a look under the hood /"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . can you dm us your account's username or email address ? we'll take a look under the hood /"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.5745
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.528244104385376
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us your email address and we'll take a look backstage / nq https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us your email address and we'll take a look backstage / nq https://t.co/ldfdzrinat"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4351
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.539556049346924
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ ! we are sorry to hear this . please dm us your account email address and we'll be happy to help . ^ mm"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ ! we are sorry to hear this . please dm us your account email address and we'll be happy to help . ^ mm"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.5122
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.4889627304077147
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there . we are sorry to hear this . please dm us your account number and phone number so we can assist you . ^ __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there . we are sorry to hear this . please dm us your account number and phone number so we can assist you . ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4333
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.417103630065918
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us with your account email address so we can look into this for you . ^ rr"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us with your account email address so we can look into this for you . ^ rr"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.5485
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.4935453567504884
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your email address and phone number and we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your email address and phone number and we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.5141
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.4478374652862547
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your email address and phone number so we can look into this for you . ^"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your email address and phone number so we can look into this for you . ^"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.5240
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.4752923583984376
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! can you dm us your account's email address ? we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! can you dm us your account's email address ? we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4980
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.4325445690155028
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , i'm sorry to hear this . please dm us your email address so we can look into this for you ? ^ hp"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , i'm sorry to hear this . please dm us your email address so we can look into this for you ? ^ hp"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.5244
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.468700527191162
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your full name , zip code , and phone number and we will look into this"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your full name , zip code , and phone number and we will look into this"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.4972
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.374319902420044
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us with your paypal email address so we can look into this for you ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us with your paypal email address so we can look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4939
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.4112120418548586
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are sorry to hear that . please dm us your email address and we'll check it out for you ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear that . please dm us your email address and we'll check it out for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3998
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.3846200075149535
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , i apologize for the inconvenience . please dm us your account info and we'll get started . - __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , i apologize for the inconvenience . please dm us your account info and we'll get started . - __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4270
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.4347686367034913
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , i am sorry to hear this . can you dm us your account's username or email address ? we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , i am sorry to hear this . can you dm us your account's username or email address ? we'll take a look backstage / __unk__ https://t.co/ldfdzrinat"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3861
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.429400661468506
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ ! we are sorry to hear this . please dm us with your paypal email address and we'll get started . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ ! we are sorry to hear this . please dm us with your paypal email address and we'll get started . https://t.co/gdrqu22ypt"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.4383
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.372315721511841
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ . please dm us your full name , zip , and phone # so we can look into this for you . ^ mw"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your full name , zip , and phone # so we can look into this for you . ^ mw"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3997
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.3577834663391113
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! thanks for reaching out to us . we are here to help . please dm us your email address and we'll get this sorted for you"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! thanks for reaching out to us . we are here to help . please dm us your email address and we'll get this sorted for you"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3408
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.387323811531067
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are here to help . please dm us your full name , zip code and details . ^ mm https://t.co/wkjhdxwgrq"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are here to help . please dm us your full name , zip code and details . ^ mm https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4353
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.3827604179382322
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are sorry to hear about this . please dm us your email address so we can connect ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear about this . please dm us your email address so we can connect ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4326
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.3128198337554933
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , sorry to hear this . please dm us your email address and we'll be happy to help ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , sorry to hear this . please dm us your email address and we'll be happy to help ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4768
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.3077019901275633
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are sorry to hear this . please dm us your tracking number and we will be happy to help . ^ kr"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this . please dm us your tracking number and we will be happy to help . ^ kr"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4093
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.422158935546875
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us your confirmation code so we can look into this for you . ^ kr"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us your confirmation code so we can look into this for you . ^ kr"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.4259
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.354220190048218
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your email address and we can look into this for you ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your email address and we can look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3824
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.333079095840454
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ . please dm us your full name , address , email , barcode , barcode , barcode , barcode , barcode , barcode , barcode ,"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your full name , address , email , barcode , barcode , barcode , barcode , barcode , barcode , barcode ,"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3572
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.3446157054901122
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us your email address and phone number so we can look into this for you ?"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us your email address and phone number so we can look into this for you ?"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3676
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.3888624143600463
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear about this . please dm us with your email address so we can look into this for you ?"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear about this . please dm us with your email address so we can look into this for you ?"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.3636
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.311639404296875
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are sorry to hear this . please dm us your confirmation number and we will look into this for you . ^ ac https://t.co/wkjhdxwgrq"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this . please dm us your confirmation number and we will look into this for you . ^ ac https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.3775
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.3098055019378663
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we're sorry to hear this . please dm us your email address so we can look into this for you ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we're sorry to hear this . please dm us your email address so we can look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 100s 100ms/step - loss: 2.3572
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.3070035705566405
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ . we have a workaround for this here : __unk__ . please dm us your confirmation number and we'll look into this for you . ^"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . we have a workaround for this here : __unk__ . please dm us your confirmation number and we'll look into this for you . ^"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.3440
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.289807333946228
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are sorry to hear this . can you dm us your account's email address ? we'll take a look backstage / cg https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this . can you dm us your account's email address ? we'll take a look backstage / cg https://t.co/ldfdzrinat"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.3866
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.3541438789367675
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are sorry to hear this . please dm us your email address and we will follow up ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this . please dm us your email address and we will follow up ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3086
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.2600177478790284
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! we are sorry to hear this . please dm us your full name , address , and phone number . ^ sc https://t.co/wkjhdxwgrq"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! we are sorry to hear this . please dm us your full name , address , and phone number . ^ sc https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3061
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.2708329238891602
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your confirmation number so we can look into this for you . thanks . ^ __unk__"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your confirmation number so we can look into this for you . thanks . ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3311
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.172768119812012
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your full name , address and email address so we can take a look . https://t.co/sxpdictw1a"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your full name , address and email address so we can take a look . https://t.co/sxpdictw1a"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3736
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.2013617458343506
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your full name , address , and phone number so we can assist . ^ mm"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your full name , address , and phone number so we can assist . ^ kd"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.3230
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.2437531070709227
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , i'm sorry to hear this . please dm us your confirmation number so we can look into this for you . - becky"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , i'm sorry to hear this . please dm us your confirmation number so we can look into this for you . - becky"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3074
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.217378849029541
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , i am sorry to hear about the service issue . please dm your account or phone number and address to chat . ^ dt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , i am sorry to hear this . please dm us your account email so we can look into this for you . thanks ! ^ __unk__"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.2382
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.209252191543579
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! can you dm us your account's username or email address ? we'll take a look backstage / cg https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! can you dm us your account's username or email address ? we'll take a look backstage / cg https://t.co/ldfdzrinat"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3027
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.2138390102386474
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your idea number and alternate number . ^ mm https://t.co/wkjhdxwgrq"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us your idea number and alternate number . ^ mm https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3406
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.211759183883667
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! can you dm us your gamertag and a screenshot of the issue ? ^ mm https://t.co/cooxeduuuc"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! can you dm us your gamertag and a screenshot of the issue ? ^ mm https://t.co/cooxeduuuc"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.2331
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.3005437259674073
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , i apologize for the inconvenience . i will be happy to help you with any questions or concerns . please send me a dm with your"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , i apologize for the inconvenience . please dm us your account number and phone number so we can look into this for you . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.3092
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.2981554832458495
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are sorry to hear this . please dm us your idea number and alternate number for further assistance . ^ mm https://t.co/wkjhdxwgrq"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this . please dm us your idea number and alternate number for further assistance . ^ mm https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.2757
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.2148356227874757
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , we are sorry to hear this . please dm us your idea number and alternate number . ^ ez"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . we are sorry to hear this . please dm us your idea number and alternate number . ^ ez"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.2827
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.2668481159210203
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! can you dm us your account's email address or username ? we'll take a look backstage / rb https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your idea number and alternate number . ^ mm https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.2952
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.225115608215332
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . can you dm us your account's email address ? we'll take a look backstage / rb https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . can you dm us your account's email address ? we'll take a look backstage / rb https://t.co/ldfdzrinat"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.2411
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.1766914234161376
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! can you dm us your account's email address ? we'll take a look backstage / dv https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your idea number and alternate number for assistance . ^ mm https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.2700
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.1792769441604616
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! can you dm us your account's email address ? we'll take a look backstage / ch https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! we are sorry to hear this . please dm us your contact number and phone number . ^ ez"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 2.2761
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.2233642292022706
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ . please dm us your tracking number , contact number , and contact number via dm . ^ ds https://t.co/wkjhdxwgrq"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . we have a great flight . ^ pa"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 2.2066
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.2516570568084715
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your idea number and alternate number . ^ ap https://t.co/wkjhdxwgrq"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , i'm sorry to hear about this . please dm us your idea number and alternate number . ^ ds https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 2.2389
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.1627157344818113
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! can you dm us your account's email address ? we'll take a look backstage / mt https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your idea number and alternate number . ^ ml https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 2.1658
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.223304481506348
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there ! can you please dm us your account's email address ? we'll take a look backstage / ay https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , i am sorry to hear this . can you please dm us your full name , address , email , barcode , supplier code , supplier code"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.2569
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.224924364089966
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . send us a dm and we'll go from there . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your confirmation number so we can look into this for you . ^ dt"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.2492
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.211244850158691
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi there , we are sorry to hear this . please dm us your confirmation number and details of your concern . ^ ez"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your confirmation number so we can look into this for you . ^ kd"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.1732
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.1439939136505126
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hey there ! can you dm us your account's email address ? we'll take a look backstage / cg https://t.co/ldfdzrinat"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear about this . please dm us your email address so we can take a look ."
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.2503
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.215186100959778
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we can help . what device are you using ?"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your tracking number , and we will look into this for you . ^ mm https://t.co/cooxeduuuc"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.2453
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.1154676094055174
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ hi , __unk__ . please dm us your confirmation number and your contact info so we can look into this for you . ^ mm https://t.co/wkjhdxwgrq"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your confirmation number so we can look into this for you . ^ mm https://t.co/cooxeduuuc"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.2230
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.1556685066223142
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we can help you out . please dm us your account email so we can look into this further . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your idea number so we can look into this for you . ^ mm https://t.co/cooxeduuuc"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.2250
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.1559173851013185
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ here to help ! send us a note at __unk__ so our team can connect ."
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there ! we don't have any info on the __unk__ . please dm us your tracking number and contact number . ^ ds https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.1280
# 1000/1000 [==============================] - 6s 6ms/step
# ...
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0181142330169677
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . let's take this to dm so we can better assist you . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0786
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0550790529251097
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . let's take this to dm so we can better assist you . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.0677
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.014198079109192
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd like to help . to start , which iphone model are you using ?"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , i would be happy to help . please dm me your account name and phone number so i can look into this & speak privately ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0667
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 1.940846612930298
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd like to help . send us a dm and we'll get started . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , i would be happy to help . please dm your name , zip code , and more details . ^ kp https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.0435
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.0922543659210207
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd be happy to look into this with you . please dm us the ios version you have installed . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , i would be happy to look into this for you . please dm your full name and zip code . ^ ds https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.0292
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.041738634109497
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . send us a dm with the country you are located in and we'll go from there . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your email address and we will look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0365
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.025292399406433
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . send us a dm with the ios version installed . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear about this . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0471
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.014300837516785
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd like to help . send us a dm with the details of the issue you're experiencing . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your email address and we'll reach out right away ."
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.0400
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.000276741027832
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . let's take this to dm so we can better assist you . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us the store location and your contact info . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 99s 99ms/step - loss: 2.0435
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 2.045993329048157
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . let's take a look at this together . dm us and we'll get started . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your email address so we can look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.1811
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0212397203445436
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . let's take a look at this together . send us a dm and let us know which device you're using and we'll go from"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , i would be happy to look into your internet issue . can you please dm me your account number ? - aaron"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.0273
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 1.9753309144973754
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . let's take a look at this together . send us a dm and let us know which device you're using and we'll go from"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , i am sorry to hear this . please dm us with your tracking number and contact phone number . ^ e . w . https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 1.9936
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.009745012283325
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . send us a dm and we'll get started . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this . can you please dm us with your order number and bakery-cafe location so we can look into this ? thanks"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 1.9727
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0106956310272217
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd like to help . let's take this to dm so we can better assist you . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 1.9921
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0052889385223387
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd like to help . send us a dm with your current ios version and we'll go from there . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , i am sorry to hear this . please dm us your full name , address , and phone number . ^ ck"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0506
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0061479434967042
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd like to help . dm us which iphone you're using and we'll go from there . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , i am sorry to hear this . please dm us with your paypal email and any applicable screenshots . ^ ez"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0281
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0213373851776124
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . dm us and we'll go from there . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your confirmation number so we can look into this for you . ^ ch https://t.co/wkjhdxwgrq"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0259
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0343303508758543
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . dm us and we'll get started . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , i am sorry to hear this . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0761
# 1000/1000 [==============================] - 7s 7ms/step
# Test results: 1.9268272256851195
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . dm us which ios version you are using and the ios version you are using . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0430
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 1.92809317111969
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd like to help . send us a dm and we'll get started . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your email address so we can look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.1538
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0013689517974855
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd like to help . please dm us which version of ios 11 you're using . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , sorry to hear about the delay . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 1.9995
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 1.9551886386871338
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . dm us which iphone you're using . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.0202
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 1.9665000610351562
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . dm us and we'll go from there . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0191
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 1.9983782539367676
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . dm us the country you're located in . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , __unk__ . please dm us your contact info and store address . thanks !"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0258
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 1.9978962783813476
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . send us a dm and we'll go from there . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we're sorry to hear about this . can you please dm us your email address and details so we can look into this for you ?"
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0565
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.0043698892593382
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . dm us and we'll get started . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this . please dm us your email address and we'll reach out right away ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.0398
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 1.987634913444519
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . dm us and we'll go from there . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this . please dm us your email address so we can look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 97s 97ms/step - loss: 1.9816
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 2.005313285827637
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we want to help . dm us and we'll go from there . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi there , we are sorry to hear this . please dm us your email address so we can look into this for you ."
# Epoch 1/1
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.0514
# 1000/1000 [==============================] - 6s 6ms/step
# Test results: 1.999239694595337
# > "@AppleSupport I fix I this I stupid I problem I"
# < "@__sn__ we'd like to help . send us a dm with more details about what's happening with your iphone . https://t.co/gdrqu22ypt"
# > "@AmazonHelp I hadnt expected that such a big brand like amazon would have such a poor customer service."
# < "@__sn__ hi , we are sorry to hear this . please dm us your email address so we can look into this ."
# Halting after 21606.05633044243 seconds spent training.

# %%
respond_to(s2s_model, '''@AppleSupport iPhone 8 touchID doesnt unlock while charging on 
    110v w/ 61w laptop charger to usbc lightning cable just uh.. so you guys know''')
# Out:
# "@__sn__ we'd like to help . send us a dm with your current ios version and we'll go from there . https://t.co/gdrqu22ypt"

# %%
respond_to(s2s_model, '''@sprintcare I can't make calls... wtf''')
# Out:
# '@__sn__ hi , __unk__ . please send us a dm with your email address so we can look into this .'

# %%
s2s_model

# %%
tf.keras.models.save_model(
    model, filepath, overwrite=True, include_optimizer=True, save_format=None,
    signatures=None, options=None, save_traces=True
)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\JiatingChen\\Documents\\nlp-coe\\twitter-conversational-chatbot\\EDA Notebooks'

# %%
import h5py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15836\3925459481.py in <module>
# ----> 1 import h5py
#
# ~\anaconda3\envs\tf_test\lib\site-packages\h5py\__init__.py in <module>
#      31         raise
#      32
# ---> 33 from . import version
#      34
#      35 if version.hdf5_version_tuple != version.hdf5_built_version_tuple:
#
# ~\anaconda3\envs\tf_test\lib\site-packages\h5py\version.py in <module>
#      13
#      14 from collections import namedtuple
# ---> 15 from . import h5 as _h5
#      16 import sys
#      17 import numpy
#
# h5py\h5.pyx in init h5py.h5()
#
# ImportError: DLL load failed: The specified procedure could not be found.

# %%
tf.keras.models.save_model(s2s_model, filepath = '../model')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15836\3267402457.py in <module>
# ----> 1 tf.keras.models.save_model(s2s_model, filepath = '../model')
#
# ~\anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\keras\saving\save.py in save_model(model, filepath, overwrite, include_optimizer, save_format)
#     111           'or using `save_weights`.')
#     112     hdf5_format.save_model_to_hdf5(
# --> 113         model, filepath, overwrite, include_optimizer)
#     114     return
#     115
#
# ~\anaconda3\envs\tf_test\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#      70
#      71   if h5py is None:
# ---> 72     raise ImportError('`save_model` requires h5py.')
#      73
#      74   from tensorflow.python.keras import __version__ as keras_version  # pylint: disable=g-import-not-at-top
#
# ImportError: `save_model` requires h5py.
