# %%
import sys
import textract, PyPDF2, glob
import nltk
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('maxent_ne_chunker')
# nltk.download('words')
# nltk.download('stopwords')
import re
import os
import subprocess
from pdfminer.high_level import extract_text
from nltk.corpus import stopwords
import string

# %%
#!pip install textract

# %%
#!pip install PyPDF2

# %%
#!pip install textract

# %%
import nltk
from nltk.tag.stanford import StanfordNERTagger

# %%
files = glob.glob(r"C:\Users\rtd91\Data\Resume.pdf")
PATH_TO_JAR = "C:\\Users\rtd91\Data\stanford-ner.jar"
PATH_TO_MODEL = "C:\\Users\rtd91\Data\english.all.3class.distsim.crf.ser.gz"
stopwords = set(stopwords.words('english'))

# %%
files1 = glob.glob(r"C:\Users\rtd91\Data\resume_samples\*")

# %%
tagger = StanfordNERTagger(model_filename=r"C:\Users\rtd91\Data\english.all.3class.distsim.crf.ser.gz",path_to_jar=r"C:\Users\rtd91\Data\stanford-ner.jar", encoding='utf-8')

# %%
txt = extract_text(files1[12])

# %%
files1[12]
# Out:
# 'C:\\Users\\rtd91\\Data\\resume_samples\\821110527_.pdf'

# %% [markdown]
# - files1[1] - Robert(821101104_phonescreening.pdf) Actual name: Harsh (Bold names)
# - files1[5] - Wang (821110445_Qizhe.pdf) Actual name : Qizhe
# - files1[6] - Eversource (821110447_rachan.pdf) Actual name : Rachan (Bold names)
# - files1[7] - Python (821110448_RAGHUVEERA.pdf) Actual name : RAGHUVEERA
# - files1[8] - Muktar i.e. last name (821110464_Saida.pdf) Actual name : Saida
# - files1[10] - Norman (821110510_AKSHARA.pdf) Actual name : Akshara
# - files1[11] -

# %%
files1[6]
# Out:
# 'C:\\Users\\rtd91\\Data\\resume_samples\\821110445_Qizhe.pdf'

# %%
words = nltk.word_tokenize(txt)

# %%
words
# Out:
# ['https',
#  ':',
#  '//www.linkedin.com/in/pranav-gulghane',
#  'Pranav',
#  'Premdas',
#  'Gulghane',
#  '+1-4695140740',
#  '|',
#  'pranavpremdasgulghane',
#  '@',
#  'gmail.com',
#  'EDUCATION',
#  'The',
#  'University',
#  'of',
#  'Texas',
#  'at',
#  'Dallas',
#  'M.S.',
#  ',',
#  'Information',
#  'Technology',
#  'and',
#  'Management',
#  'December',
#  '2021',
#  'Deans',
#  'Excellence',
#  'Scholarship',
#  'Recipient',
#  'GPA',
#  ':',
#  '3.91',
#  'June',
#  '2019',
#  'GPA',
#  ':',
#  '3.7',
#  'Savitribai',
#  'Phule',
#  'Pune',
#  'University',
#  ',',
#  'Pune',
#  'B.E',
#  '.',
#  'Electronics',
#  'and',
#  'Telecommunication',
#  'Engineering',
#  'EXPERIENCE',
#  'Accenture',
#  'Data',
#  'Analyst',
#  'Sage',
#  'Intacct',
#  ',',
#  'California',
#  'June',
#  '2021-',
#  'Present',
#  'Business',
#  'Intelligence',
#  'Analyst',
#  'Intern',
#  '•',
#  'Manipulate',
#  'and',
#  'analyze',
#  'large',
#  'data',
#  'sets',
#  'in',
#  'Oracle',
#  'Database',
#  'using',
#  'SQL',
#  'Techniques',
#  'to',
#  'distill',
#  'insights',
#  'from',
#  'data',
#  'trends',
#  'and',
#  'forecasts',
#  '.',
#  '•',
#  'Managed',
#  'the',
#  'Salesforce',
#  'service',
#  'request',
#  'and',
#  'provided',
#  '100',
#  'percent',
#  'support',
#  'to',
#  'the',
#  'teams',
#  'the',
#  'very',
#  'same',
#  'day',
#  '.',
#  '•',
#  'Used',
#  'sales',
#  'trends',
#  ',',
#  'marketing',
#  ',',
#  'accounting',
#  ',',
#  'and',
#  'customer',
#  'usage',
#  'data',
#  'to',
#  'create',
#  'and',
#  'maintain',
#  'standardized',
#  'dashboards',
#  ',',
#  'metrics',
#  ',',
#  'KPIs',
#  ',',
#  'and',
#  'reports',
#  '.',
#  'Tableau',
#  'project',
#  'structure',
#  'and',
#  'permission',
#  'management',
#  '.',
#  'Partnered',
#  'with',
#  'architecture',
#  'and',
#  'other',
#  'senior',
#  'leads',
#  'to',
#  'address',
#  'the',
#  'data',
#  'needs',
#  'of',
#  'our',
#  'rapidly',
#  'growing',
#  'business',
#  '.',
#  '•',
#  'Automated',
#  'Tableau',
#  'Refresh',
#  'Extract',
#  'via',
#  'API',
#  'calls',
#  'by',
#  'writing',
#  'a',
#  'python',
#  'script',
#  ',',
#  'saving',
#  '4',
#  'hours',
#  'per',
#  'week',
#  '.',
#  '•',
#  '•',
#  'Gathering',
#  'requirements',
#  'from',
#  'various',
#  'teams',
#  'and',
#  'suggesting',
#  'ways',
#  'to',
#  'improve',
#  'the',
#  'dashboard',
#  '.',
#  '•',
#  'Managed',
#  'user',
#  'access',
#  'to',
#  'Tableau',
#  'tools',
#  'in',
#  'accordance',
#  'with',
#  'data',
#  'governance',
#  'security',
#  'requirements',
#  '.',
#  '•',
#  '•',
#  'Created',
#  'Data',
#  'Dictionary',
#  'and',
#  'Metadata',
#  'of',
#  'Workbooks',
#  'and',
#  'Data',
#  'sources',
#  'and',
#  'documented',
#  'those',
#  'for',
#  'the',
#  'organization',
#  '.',
#  'Identifying',
#  'statistically',
#  'significant',
#  'patterns',
#  ',',
#  'correlations',
#  ',',
#  'and',
#  'compiling',
#  'questions',
#  'raised',
#  'by',
#  'team',
#  '.',
#  'Oct',
#  '2019',
#  '-',
#  'Dec',
#  '2019',
#  '•',
#  'Implemented',
#  'logical',
#  'query',
#  'optimization',
#  'using',
#  'SQL',
#  'techniques',
#  'and',
#  'minimized',
#  'the',
#  'query',
#  'execution',
#  'time',
#  'by',
#  '10',
#  '%',
#  'enhancing',
#  'the',
#  'overall',
#  'productivity',
#  'of',
#  'the',
#  'deliverable',
#  '.',
#  '•',
#  'Created',
#  'reports',
#  ',',
#  'dashboards',
#  'on',
#  'data',
#  'associated',
#  'with',
#  'customers',
#  ',',
#  'business',
#  'processes',
#  ',',
#  'market',
#  'economics',
#  ',',
#  'to',
#  'provide',
#  'insights',
#  'to',
#  'senior',
#  'management',
#  'and',
#  'business',
#  'leaders',
#  'in',
#  'support',
#  'of',
#  'decision-making',
#  'efforts',
#  '.',
#  '•',
#  'Performed',
#  'data',
#  'cleaning',
#  'using',
#  'Python',
#  'and',
#  'analyzed',
#  'key',
#  'metrics',
#  'using',
#  'Tableau',
#  'reducing',
#  'customer',
#  'churn',
#  'by',
#  '5',
#  '%',
#  '.',
#  'Jan',
#  '2019',
#  '-',
#  'Aug',
#  '2019',
#  'Cain',
#  'Industries',
#  'Business',
#  'Data',
#  'Analyst',
#  'Intern',
#  '•',
#  '•',
#  '•',
#  '•',
#  '•',
#  'Performed',
#  'market',
#  'analysis',
#  ',',
#  'analyzing',
#  'both',
#  'product',
#  'lines',
#  'and',
#  'the',
#  'overall',
#  'profitability',
#  'of',
#  'the',
#  'business',
#  'by',
#  '18',
#  'percent',
#  '.',
#  'Documented',
#  'research',
#  'findings',
#  ',',
#  'penetrating',
#  'deep',
#  'in',
#  'market',
#  'from',
#  'the',
#  'customers',
#  'surveys',
#  ',',
#  'comments',
#  ',',
#  'and',
#  'reviews',
#  ',',
#  'Employee',
#  'surveys',
#  ',',
#  'Customer',
#  'data',
#  'collection',
#  ',',
#  'Third-party',
#  'research',
#  'and',
#  'data',
#  '.',
#  'Presented',
#  'Insights',
#  '&',
#  'Reports',
#  'Based',
#  'on',
#  'the',
#  'Interpretation',
#  'of',
#  'Data',
#  'in',
#  'Excel',
#  'and',
#  'Tableau',
#  'for',
#  'data',
#  'reporting',
#  'by',
#  'using',
#  'pivot',
#  'tables',
#  '.',
#  'Contributed',
#  'to',
#  'Important',
#  'Business',
#  'Decisions',
#  'helped',
#  'the',
#  'marketing',
#  ',',
#  'sales',
#  ',',
#  'and',
#  'customer',
#  'experience',
#  'teams',
#  'understand',
#  'which',
#  'strategies',
#  'are',
#  'worth',
#  'investing',
#  'in',
#  'further',
#  '.',
#  'Developed',
#  'a',
#  'process',
#  'to',
#  'track',
#  'interplant',
#  'inventory',
#  'movements',
#  'based',
#  'on',
#  'several',
#  'factors',
#  ',',
#  'reducing',
#  'manual',
#  'processing',
#  'time',
#  'by',
#  'over',
#  '88',
#  '%',
#  '.',
#  'Provided',
#  'competitive',
#  'analyses',
#  'with',
#  'three',
#  'companies',
#  ',',
#  'comparing',
#  'competitor',
#  '’',
#  's',
#  'position',
#  'in',
#  'the',
#  'market',
#  ',',
#  'their',
#  'pricing',
#  ',',
#  'and',
#  'their',
#  'marketing',
#  'strategies',
#  '.',
#  'Conducted',
#  'the',
#  'SWOT',
#  'Analysis',
#  'which',
#  'improved',
#  'the',
#  'outcome',
#  'by',
#  '15',
#  'percent',
#  '.',
#  'PROJECTS',
#  'Marketing',
#  'Analytics',
#  '/',
#  'Google',
#  'Campaign',
#  '(',
#  'Google',
#  'Analytics',
#  ',',
#  'Google',
#  'Ad',
#  'Words',
#  ')',
#  'Sept',
#  '2020',
#  '•',
#  'Led',
#  'the',
#  'strategy',
#  'and',
#  'implementation',
#  'of',
#  'a',
#  'Google',
#  'Ad',
#  'campaign',
#  'to',
#  'maximize',
#  'brand',
#  'awareness',
#  'and',
#  'create',
#  'CTR',
#  'and',
#  'TCR',
#  ',',
#  'statistically',
#  'boosting',
#  'page',
#  'reviews',
#  'by',
#  'A/B',
#  'Testing',
#  'and',
#  'SEO',
#  '.',
#  '•',
#  'Used',
#  'Google',
#  'Analytics',
#  'to',
#  'track',
#  'most',
#  'searched',
#  'data',
#  'for',
#  'recommendations',
#  'which',
#  'improved',
#  'CTR',
#  'and',
#  'improved',
#  'the',
#  'online',
#  'sale',
#  'by',
#  '30',
#  'Truck',
#  'Fleet',
#  'Risk',
#  'Analysis',
#  '–',
#  '(',
#  'Hadoop',
#  ',',
#  'Flume',
#  ',',
#  'Pig',
#  ',',
#  'Hive',
#  ',',
#  'R',
#  ',',
#  'Tableau',
#  ')',
#  'June',
#  '2020',
#  'Created',
#  'Process',
#  'flow',
#  'in',
#  'Hadoop',
#  'ecosystem',
#  'to',
#  'calculate',
#  'risk',
#  'factors',
#  'using',
#  'pig',
#  'script',
#  ',',
#  'then',
#  'imported',
#  ',',
#  'created',
#  ',',
#  'loaded',
#  'truck',
#  'fleet',
#  'dataset',
#  'into',
#  'Hive',
#  'tables',
#  '.',
#  'Implemented',
#  'a',
#  'logistic',
#  'regression',
#  'model',
#  'in',
#  'R',
#  'to',
#  'identify',
#  'risky',
#  'drivers',
#  'also',
#  'created',
#  'interactive',
#  'dashboard',
#  'in',
#  'tableau',
#  'to',
#  'pinpoint',
#  'risky',
#  'drivers',
#  'in',
#  'regression',
#  'model',
#  'based',
#  'on',
#  'geographic',
#  'area',
#  'and',
#  'time',
#  '.',
#  'Analyzed',
#  'dataset',
#  'of',
#  'United',
#  'States',
#  'car',
#  'resale',
#  ',',
#  'achieved',
#  'insightful',
#  'analysis',
#  'of',
#  'features',
#  'by',
#  'performing',
#  'EDA',
#  '.',
#  'Implemented',
#  'linear',
#  'regression',
#  'and',
#  'KNN',
#  'model',
#  ',',
#  'performed',
#  'feature',
#  'extraction',
#  'using',
#  'backward',
#  'regression',
#  'and',
#  'AIC',
#  'technique',
#  '.',
#  'percent',
#  '.',
#  '•',
#  '•',
#  '•',
#  '•',
#  'CERTIFICATIONS',
#  '&',
#  'TECHNICAL',
#  'SKILLS',
#  'Certifications',
#  ':',
#  'Google',
#  'Analytics',
#  ',',
#  'Google',
#  'AdWords',
#  ',',
#  'Google',
#  'Ad',
#  'Display',
#  ',',
#  'Google',
#  'Ad',
#  'Search',
#  'Certification',
#  'Analysis',
#  'Tools',
#  ':',
#  'Tableau',
#  ',',
#  'Power',
#  'BI',
#  ',',
#  'MS-Excel',
#  ',',
#  'R',
#  'Studio',
#  'Programming',
#  ':',
#  'Java',
#  ',',
#  'Python',
#  ',',
#  'R',
#  ',',
#  'SQL',
#  'Software',
#  'Tools',
#  ':',
#  'MS-Excel',
#  ',',
#  'MS-Word',
#  ',',
#  'MS-Visio',
#  ',',
#  'Jupyter',
#  'Notebook',
#  ',',
#  'Oracle',
#  'Database',
#  ',',
#  'Tableau',
#  'Desktop',
#  ',',
#  'Salesforce',
#  'Databases',
#  ':',
#  'MySQL',
#  ',',
#  'MS-Access',
#  ',',
#  'SQL-Server',
#  'Business',
#  'Decision',
#  'Tool',
#  '(',
#  'Car',
#  'Price',
#  'Prediction',
#  ')',
#  '–',
#  '(',
#  'R',
#  ',',
#  'gplot',
#  ',',
#  'forecast',
#  ')',
#  'May',
#  '2020']

# %%
acceptible = set(chr(i) for i in range(0x21, 0xFF + 1))
simple_strings = [word for i in acceptible for word in words if i in word]

# %%
simple_strings1 = [word for word in simple_strings if word not in stopwords if word not in string.punctuation]

# %%
res = [re.sub(r'[^\w\s]', '', word) for word in simple_strings1]

# %%
res1 = [re.sub(r'^abc(.*?)=[A-Z0-9]+(.*)', r'\1\2', word) for word in res]

# %%
res2 = [str(res) for res in res1]

# %%
res3 = [re.sub(r'/^[A-Za-z]+$/', '', res) for res in res2]

# %%
res3 = [res.replace("ï","i") if "ï" in res else res for res in res3]

# %%
tagged = tagger.tag(res3)

# %%
tagged
# Out:
# [('wwwlinkedincominpranavgulghane', 'O'),
#  ('gmailcom', 'O'),
#  ('Technology', 'O'),
#  ('December', 'O'),
#  ('Excellence', 'O'),
#  ('Scholarship', 'O'),
#  ('Recipient', 'O'),
#  ('Electronics', 'O'),
#  ('Telecommunication', 'O'),
#  ('Accenture', 'ORGANIZATION'),
#  ('Intacct', 'ORGANIZATION'),
#  ('Intelligence', 'ORGANIZATION'),
#  ('Oracle', 'ORGANIZATION'),
#  ('Techniques', 'ORGANIZATION'),
#  ('forecasts', 'O'),
#  ('Salesforce', 'O'),
#  ('service', 'O'),
#  ('percent', 'O'),
#  ('accounting', 'O'),
#  ('customer', 'O'),
#  ('create', 'O'),
#  ('metrics', 'O'),
#  ('project', 'O'),
#  ('structure', 'O'),
#  ('architecture', 'O'),
#  ('Extract', 'O'),
#  ('calls', 'O'),
#  ('script', 'O'),
#  ('access', 'O'),
#  ('accordance', 'O'),
#  ('governance', 'O'),
#  ('security', 'O'),
#  ('Dictionary', 'O'),
#  ('sources', 'O'),
#  ('documented', 'O'),
#  ('statistically', 'O'),
#  ('significant', 'O'),
#  ('correlations', 'O'),
#  ('compiling', 'O'),
#  ('Oct', 'O'),
#  ('Dec', 'O'),
#  ('logical', 'O'),
#  ('techniques', 'O'),
#  ('execution', 'O'),
#  ('enhancing', 'O'),
#  ('productivity', 'O'),
#  ('associated', 'O'),
#  ('customers', 'O'),
#  ('processes', 'O'),
#  ('economics', 'O'),
#  ('decisionmaking', 'O'),
#  ('cleaning', 'O'),
#  ('metrics', 'O'),
#  ('reducing', 'O'),
#  ('customer', 'O'),
#  ('churn', 'O'),
#  ('product', 'O'),
#  ('percent', 'O'),
#  ('Documented', 'O'),
#  ('research', 'O'),
#  ('customers', 'O'),
#  ('comments', 'O'),
#  ('collection', 'O'),
#  ('research', 'O'),
#  ('Excel', 'O'),
#  ('Decisions', 'O'),
#  ('customer', 'O'),
#  ('experience', 'O'),
#  ('process', 'O'),
#  ('track', 'O'),
#  ('factors', 'O'),
#  ('reducing', 'O'),
#  ('processing', 'O'),
#  ('competitive', 'O'),
#  ('companies', 'O'),
#  ('comparing', 'O'),
#  ('competitor', 'O'),
#  ('pricing', 'O'),
#  ('Conducted', 'O'),
#  ('outcome', 'O'),
#  ('percent', 'O'),
#  ('Analytics', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('campaign', 'O'),
#  ('create', 'O'),
#  ('statistically', 'O'),
#  ('Analytics', 'O'),
#  ('track', 'O'),
#  ('searched', 'O'),
#  ('recommendations', 'O'),
#  ('Truck', 'O'),
#  ('Process', 'O'),
#  ('ecosystem', 'O'),
#  ('calculate', 'O'),
#  ('factors', 'O'),
#  ('script', 'O'),
#  ('created', 'O'),
#  ('truck', 'O'),
#  ('logistic', 'O'),
#  ('created', 'O'),
#  ('interactive', 'O'),
#  ('geographic', 'O'),
#  ('car', 'O'),
#  ('achieved', 'O'),
#  ('extraction', 'O'),
#  ('backward', 'O'),
#  ('technique', 'O'),
#  ('percent', 'O'),
#  ('Certifications', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('Search', 'ORGANIZATION'),
#  ('Certification', 'ORGANIZATION'),
#  ('MSExcel', 'ORGANIZATION'),
#  ('MSExcel', 'O'),
#  ('Oracle', 'O'),
#  ('Salesforce', 'O'),
#  ('MSAccess', 'O'),
#  ('Decision', 'O'),
#  ('Price', 'O'),
#  ('Prediction', 'O'),
#  ('forecast', 'O'),
#  ('wwwlinkedincominpranavgulghane', 'O'),
#  ('AB', 'O'),
#  ('wwwlinkedincominpranavgulghane', 'O'),
#  ('Gulghane', 'O'),
#  ('pranavpremdasgulghane', 'O'),
#  ('gmailcom', 'O'),
#  ('Technology', 'ORGANIZATION'),
#  ('Management', 'ORGANIZATION'),
#  ('Engineering', 'ORGANIZATION'),
#  ('Sage', 'ORGANIZATION'),
#  ('Intelligence', 'ORGANIZATION'),
#  ('large', 'O'),
#  ('using', 'O'),
#  ('insights', 'O'),
#  ('Managed', 'O'),
#  ('marketing', 'O'),
#  ('accounting', 'O'),
#  ('usage', 'O'),
#  ('management', 'O'),
#  ('growing', 'O'),
#  ('writing', 'O'),
#  ('saving', 'O'),
#  ('Gathering', 'O'),
#  ('suggesting', 'O'),
#  ('Managed', 'O'),
#  ('governance', 'O'),
#  ('organization', 'O'),
#  ('Identifying', 'O'),
#  ('significant', 'O'),
#  ('compiling', 'O'),
#  ('logical', 'O'),
#  ('using', 'O'),
#  ('enhancing', 'O'),
#  ('insights', 'O'),
#  ('management', 'O'),
#  ('decisionmaking', 'O'),
#  ('cleaning', 'O'),
#  ('using', 'O'),
#  ('using', 'O'),
#  ('reducing', 'O'),
#  ('Aug', 'O'),
#  ('analyzing', 'O'),
#  ('findings', 'O'),
#  ('penetrating', 'O'),
#  ('Insights', 'O'),
#  ('reporting', 'O'),
#  ('using', 'O'),
#  ('marketing', 'O'),
#  ('strategies', 'O'),
#  ('investing', 'O'),
#  ('reducing', 'O'),
#  ('processing', 'O'),
#  ('comparing', 'O'),
#  ('pricing', 'O'),
#  ('marketing', 'O'),
#  ('strategies', 'O'),
#  ('Marketing', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Campaign', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('strategy', 'O'),
#  ('Google', 'ORGANIZATION'),
#  ('campaign', 'O'),
#  ('boosting', 'O'),
#  ('page', 'O'),
#  ('Testing', 'O'),
#  ('Google', 'O'),
#  ('Pig', 'O'),
#  ('using', 'O'),
#  ('pig', 'O'),
#  ('logistic', 'O'),
#  ('regression', 'O'),
#  ('regression', 'O'),
#  ('geographic', 'O'),
#  ('insightful', 'O'),
#  ('performing', 'O'),
#  ('regression', 'O'),
#  ('using', 'O'),
#  ('regression', 'O'),
#  ('Google', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Programming', 'O'),
#  ('gplot', 'O'),
#  ('EDUCATION', 'O'),
#  ('EXPERIENCE', 'O'),
#  ('KNN', 'O'),
#  ('CERTIFICATIONS', 'O'),
#  ('TECHNICAL', 'O'),
#  ('Notebook', 'O'),
#  ('https', 'O'),
#  ('University', 'ORGANIZATION'),
#  ('Information', 'ORGANIZATION'),
#  ('Management', 'ORGANIZATION'),
#  ('Recipient', 'ORGANIZATION'),
#  ('Savitribai', 'ORGANIZATION'),
#  ('University', 'ORGANIZATION'),
#  ('Electronics', 'ORGANIZATION'),
#  ('Telecommunication', 'ORGANIZATION'),
#  ('Accenture', 'ORGANIZATION'),
#  ('Data', 'ORGANIZATION'),
#  ('Analyst', 'ORGANIZATION'),
#  ('Intacct', 'ORGANIZATION'),
#  ('Present', 'ORGANIZATION'),
#  ('Intelligence', 'ORGANIZATION'),
#  ('Analyst', 'O'),
#  ('Intern', 'O'),
#  ('Manipulate', 'O'),
#  ('data', 'O'),
#  ('sets', 'O'),
#  ('Database', 'O'),
#  ('distill', 'O'),
#  ('insights', 'O'),
#  ('data', 'O'),
#  ('trends', 'O'),
#  ('forecasts', 'O'),
#  ('request', 'O'),
#  ('percent', 'O'),
#  ('support', 'O'),
#  ('teams', 'O'),
#  ('trends', 'O'),
#  ('marketing', 'O'),
#  ('accounting', 'O'),
#  ('customer', 'O'),
#  ('data', 'O'),
#  ('create', 'O'),
#  ('maintain', 'O'),
#  ('standardized', 'O'),
#  ('metrics', 'O'),
#  ('reports', 'O'),
#  ('project', 'O'),
#  ('structure', 'O'),
#  ('management', 'O'),
#  ('Partnered', 'O'),
#  ('architecture', 'O'),
#  ('data', 'O'),
#  ('Automated', 'O'),
#  ('Extract', 'O'),
#  ('writing', 'O'),
#  ('python', 'O'),
#  ('script', 'O'),
#  ('Gathering', 'O'),
#  ('requirements', 'O'),
#  ('teams', 'O'),
#  ('suggesting', 'O'),
#  ('tools', 'O'),
#  ('data', 'O'),
#  ('security', 'O'),
#  ('requirements', 'O'),
#  ('Created', 'ORGANIZATION'),
#  ('Data', 'ORGANIZATION'),
#  ('Dictionary', 'ORGANIZATION'),
#  ('Metadata', 'ORGANIZATION'),
#  ('Data', 'ORGANIZATION'),
#  ('documented', 'O'),
#  ('organization', 'O'),
#  ('Identifying', 'O'),
#  ('statistically', 'O'),
#  ('significant', 'O'),
#  ('patterns', 'O'),
#  ('correlations', 'O'),
#  ('questions', 'O'),
#  ('team', 'O'),
#  ('Oct', 'O'),
#  ('Implemented', 'O'),
#  ('optimization', 'O'),
#  ('techniques', 'O'),
#  ('execution', 'O'),
#  ('time', 'O'),
#  ('productivity', 'O'),
#  ('Created', 'O'),
#  ('reports', 'O'),
#  ('data', 'O'),
#  ('associated', 'O'),
#  ('customers', 'O'),
#  ('market', 'O'),
#  ('insights', 'O'),
#  ('management', 'O'),
#  ('support', 'O'),
#  ('efforts', 'O'),
#  ('data', 'O'),
#  ('Python', 'O'),
#  ('metrics', 'O'),
#  ('customer', 'O'),
#  ('Industries', 'O'),
#  ('Data', 'O'),
#  ('Analyst', 'O'),
#  ('Intern', 'O'),
#  ('market', 'O'),
#  ('product', 'O'),
#  ('profitability', 'O'),
#  ('percent', 'O'),
#  ('Documented', 'O'),
#  ('penetrating', 'O'),
#  ('market', 'O'),
#  ('customers', 'O'),
#  ('comments', 'O'),
#  ('Customer', 'O'),
#  ('data', 'O'),
#  ('collection', 'O'),
#  ('Thirdparty', 'O'),
#  ('data', 'O'),
#  ('Presented', 'O'),
#  ('Insights', 'O'),
#  ('Reports', 'O'),
#  ('Interpretation', 'O'),
#  ('Data', 'O'),
#  ('data', 'O'),
#  ('reporting', 'O'),
#  ('pivot', 'O'),
#  ('tables', 'O'),
#  ('Contributed', 'O'),
#  ('Important', 'O'),
#  ('marketing', 'O'),
#  ('customer', 'O'),
#  ('teams', 'O'),
#  ('understand', 'O'),
#  ('strategies', 'O'),
#  ('worth', 'O'),
#  ('investing', 'O'),
#  ('track', 'O'),
#  ('interplant', 'O'),
#  ('inventory', 'O'),
#  ('movements', 'O'),
#  ('factors', 'O'),
#  ('time', 'O'),
#  ('competitive', 'O'),
#  ('three', 'O'),
#  ('competitor', 'O'),
#  ('position', 'O'),
#  ('market', 'O'),
#  ('marketing', 'O'),
#  ('strategies', 'O'),
#  ('Conducted', 'O'),
#  ('outcome', 'O'),
#  ('percent', 'O'),
#  ('Marketing', 'O'),
#  ('Analytics', 'O'),
#  ('Analytics', 'O'),
#  ('Sept', 'O'),
#  ('strategy', 'O'),
#  ('implementation', 'O'),
#  ('create', 'O'),
#  ('statistically', 'O'),
#  ('boosting', 'O'),
#  ('Testing', 'O'),
#  ('Analytics', 'O'),
#  ('track', 'O'),
#  ('data', 'O'),
#  ('recommendations', 'O'),
#  ('Fleet', 'O'),
#  ('Created', 'O'),
#  ('ecosystem', 'O'),
#  ('calculate', 'O'),
#  ('factors', 'O'),
#  ('script', 'O'),
#  ('imported', 'O'),
#  ('created', 'O'),
#  ('truck', 'O'),
#  ('fleet', 'O'),
#  ('dataset', 'O'),
#  ('tables', 'O'),
#  ('Implemented', 'O'),
#  ('logistic', 'O'),
#  ('identify', 'O'),
#  ('created', 'O'),
#  ('interactive', 'O'),
#  ('tableau', 'O'),
#  ('pinpoint', 'O'),
#  ('time', 'O'),
#  ('dataset', 'O'),
#  ('United', 'LOCATION'),
#  ('States', 'LOCATION'),
#  ('insightful', 'O'),
#  ('features', 'O'),
#  ('Implemented', 'O'),
#  ('feature', 'O'),
#  ('extraction', 'O'),
#  ('technique', 'O'),
#  ('percent', 'O'),
#  ('Certifications', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('Certification', 'ORGANIZATION'),
#  ('Studio', 'ORGANIZATION'),
#  ('Python', 'ORGANIZATION'),
#  ('Software', 'ORGANIZATION'),
#  ('Jupyter', 'ORGANIZATION'),
#  ('Notebook', 'ORGANIZATION'),
#  ('Database', 'ORGANIZATION'),
#  ('Desktop', 'ORGANIZATION'),
#  ('Databases', 'ORGANIZATION'),
#  ('Prediction', 'ORGANIZATION'),
#  ('gplot', 'O'),
#  ('forecast', 'O'),
#  ('14695140740', 'O'),
#  ('4', 'O'),
#  ('wwwlinkedincominpranavgulghane', 'O'),
#  ('Pranav', 'O'),
#  ('Gulghane', 'O'),
#  ('pranavpremdasgulghane', 'O'),
#  ('University', 'ORGANIZATION'),
#  ('Information', 'ORGANIZATION'),
#  ('Technology', 'ORGANIZATION'),
#  ('Management', 'ORGANIZATION'),
#  ('Deans', 'ORGANIZATION'),
#  ('Excellence', 'ORGANIZATION'),
#  ('Recipient', 'ORGANIZATION'),
#  ('June', 'ORGANIZATION'),
#  ('Pune', 'ORGANIZATION'),
#  ('University', 'ORGANIZATION'),
#  ('Pune', 'ORGANIZATION'),
#  ('Electronics', 'ORGANIZATION'),
#  ('Telecommunication', 'ORGANIZATION'),
#  ('Engineering', 'ORGANIZATION'),
#  ('Accenture', 'ORGANIZATION'),
#  ('Analyst', 'O'),
#  ('Intacct', 'O'),
#  ('California', 'LOCATION'),
#  ('June', 'O'),
#  ('Present', 'O'),
#  ('Business', 'O'),
#  ('Intelligence', 'O'),
#  ('Analyst', 'O'),
#  ('Intern', 'O'),
#  ('Manipulate', 'O'),
#  ('analyze', 'O'),
#  ('using', 'O'),
#  ('Techniques', 'O'),
#  ('insights', 'O'),
#  ('trends', 'O'),
#  ('Managed', 'O'),
#  ('percent', 'O'),
#  ('trends', 'O'),
#  ('marketing', 'O'),
#  ('accounting', 'O'),
#  ('maintain', 'O'),
#  ('standardized', 'O'),
#  ('permission', 'O'),
#  ('management', 'O'),
#  ('Partnered', 'O'),
#  ('senior', 'O'),
#  ('needs', 'O'),
#  ('growing', 'O'),
#  ('business', 'O'),
#  ('writing', 'O'),
#  ('python', 'O'),
#  ('saving', 'O'),
#  ('Gathering', 'O'),
#  ('requirements', 'O'),
#  ('suggesting', 'O'),
#  ('Managed', 'O'),
#  ('accordance', 'O'),
#  ('governance', 'O'),
#  ('requirements', 'O'),
#  ('Dictionary', 'O'),
#  ('documented', 'O'),
#  ('organization', 'O'),
#  ('Identifying', 'O'),
#  ('significant', 'O'),
#  ('patterns', 'O'),
#  ('correlations', 'O'),
#  ('compiling', 'O'),
#  ('questions', 'O'),
#  ('Implemented', 'O'),
#  ('optimization', 'O'),
#  ('using', 'O'),
#  ('techniques', 'O'),
#  ('minimized', 'O'),
#  ('execution', 'O'),
#  ('enhancing', 'O'),
#  ('business', 'O'),
#  ('economics', 'O'),
#  ('insights', 'O'),
#  ('senior', 'O'),
#  ('management', 'O'),
#  ('business', 'O'),
#  ('decisionmaking', 'O'),
#  ('cleaning', 'O'),
#  ('using', 'O'),
#  ('Python', 'PERSON'),
#  ('analyzed', 'O'),
#  ('using', 'O'),
#  ('reducing', 'O'),
#  ('churn', 'O'),
#  ('Jan', 'O'),
#  ('Cain', 'O'),
#  ('Industries', 'O'),
#  ('Business', 'O'),
#  ('Analyst', 'O'),
#  ('Intern', 'O'),
#  ('analysis', 'O'),
#  ('analyzing', 'O'),
#  ('lines', 'O'),
#  ('business', 'O'),
#  ('percent', 'O'),
#  ('Documented', 'O'),
#  ('findings', 'O'),
#  ('penetrating', 'O'),
#  ('comments', 'O'),
#  ('collection', 'O'),
#  ('Presented', 'O'),
#  ('Insights', 'O'),
#  ('Interpretation', 'O'),
#  ('reporting', 'O'),
#  ('using', 'O'),
#  ('Contributed', 'O'),
#  ('Important', 'O'),
#  ('Business', 'O'),
#  ('Decisions', 'O'),
#  ('marketing', 'O'),
#  ('experience', 'O'),
#  ('understand', 'O'),
#  ('investing', 'O'),
#  ('interplant', 'O'),
#  ('inventory', 'O'),
#  ('movements', 'O'),
#  ('reducing', 'O'),
#  ('manual', 'O'),
#  ('processing', 'O'),
#  ('analyses', 'O'),
#  ('companies', 'O'),
#  ('comparing', 'O'),
#  ('position', 'O'),
#  ('pricing', 'O'),
#  ('marketing', 'O'),
#  ('Conducted', 'O'),
#  ('Analysis', 'O'),
#  ('percent', 'O'),
#  ('Marketing', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('Campaign', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('implementation', 'O'),
#  ('campaign', 'O'),
#  ('brand', 'O'),
#  ('awareness', 'O'),
#  ('boosting', 'O'),
#  ('Testing', 'O'),
#  ('Analytics', 'O'),
#  ('recommendations', 'O'),
#  ('online', 'O'),
#  ('Analysis', 'O'),
#  ('June', 'O'),
#  ('using', 'O'),
#  ('Implemented', 'O'),
#  ('regression', 'O'),
#  ('identify', 'O'),
#  ('interactive', 'O'),
#  ('pinpoint', 'O'),
#  ('regression', 'O'),
#  ('Analyzed', 'O'),
#  ('United', 'O'),
#  ('insightful', 'O'),
#  ('analysis', 'O'),
#  ('performing', 'O'),
#  ('Implemented', 'O'),
#  ('linear', 'O'),
#  ('regression', 'O'),
#  ('extraction', 'O'),
#  ('using', 'O'),
#  ('regression', 'O'),
#  ('technique', 'O'),
#  ('percent', 'O'),
#  ('Certifications', 'O'),
#  ('Analytics', 'O'),
#  ('Certification', 'O'),
#  ('Analysis', 'O'),
#  ('Programming', 'O'),
#  ('Python', 'O'),
#  ('Business', 'O'),
#  ('Decision', 'O'),
#  ('Prediction', 'O'),
#  ('Texas', 'O'),
#  ('Excellence', 'O'),
#  ('Extract', 'O'),
#  ('execution', 'O'),
#  ('Excel', 'O'),
#  ('experience', 'O'),
#  ('maximize', 'O'),
#  ('extraction', 'O'),
#  ('MSExcel', 'O'),
#  ('MSExcel', 'O'),
#  ('wwwlinkedincominpranavgulghane', 'O'),
#  ('gmailcom', 'O'),
#  ('MS', 'O'),
#  ('391', 'O'),
#  ('37', 'O'),
#  ('BE', 'O'),
#  ('2021', 'O'),
#  ('2019', 'O'),
#  ('2021', 'O'),
#  ('2019', 'O'),
#  ('2019', 'O'),
#  ('2019', 'O'),
#  ('2019', 'O'),
#  ('2020', 'O'),
#  ('2020', 'O'),
#  ('2020', 'O'),
#  ('wwwlinkedincominpranavgulghane', 'O'),
#  ('Gulghane', 'O'),
#  ('pranavpremdasgulghane', 'O'),
#  ('gmailcom', 'O'),
#  ('Dallas', 'ORGANIZATION'),
#  ('Technology', 'ORGANIZATION'),
#  ('Excellence', 'ORGANIZATION'),
#  ('Scholarship', 'ORGANIZATION'),
#  ('Phule', 'ORGANIZATION'),
#  ('Electronics', 'ORGANIZATION'),
#  ('Telecommunication', 'ORGANIZATION'),
#  ('Analyst', 'ORGANIZATION'),
#  ('California', 'ORGANIZATION'),
#  ('Intelligence', 'ORGANIZATION'),
#  ('Analyst', 'O'),
#  ('Manipulate', 'O'),
#  ('analyze', 'O'),
#  ('large', 'O'),
#  ('Oracle', 'O'),
#  ('distill', 'O'),
#  ('Salesforce', 'O'),
#  ('sales', 'O'),
#  ('Tableau', 'O'),
#  ('leads', 'O'),
#  ('rapidly', 'O'),
#  ('Tableau', 'O'),
#  ('calls', 'O'),
#  ('Tableau', 'O'),
#  ('tools', 'O'),
#  ('statistically', 'O'),
#  ('correlations', 'O'),
#  ('compiling', 'O'),
#  ('Implemented', 'O'),
#  ('logical', 'O'),
#  ('overall', 'O'),
#  ('deliverable', 'O'),
#  ('leaders', 'O'),
#  ('cleaning', 'O'),
#  ('analyzed', 'O'),
#  ('Tableau', 'O'),
#  ('Analyst', 'O'),
#  ('analysis', 'O'),
#  ('analyzing', 'O'),
#  ('lines', 'O'),
#  ('overall', 'O'),
#  ('profitability', 'O'),
#  ('Employee', 'O'),
#  ('collection', 'O'),
#  ('Excel', 'O'),
#  ('Tableau', 'O'),
#  ('tables', 'O'),
#  ('helped', 'O'),
#  ('sales', 'O'),
#  ('Developed', 'O'),
#  ('interplant', 'O'),
#  ('several', 'O'),
#  ('manual', 'O'),
#  ('analyses', 'O'),
#  ('Analysis', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('implementation', 'O'),
#  ('Google', 'ORGANIZATION'),
#  ('statistically', 'O'),
#  ('Google', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('online', 'O'),
#  ('sale', 'O'),
#  ('Fleet', 'O'),
#  ('Analysis', 'O'),
#  ('Flume', 'O'),
#  ('Tableau', 'O'),
#  ('flow', 'O'),
#  ('calculate', 'O'),
#  ('loaded', 'O'),
#  ('fleet', 'O'),
#  ('tables', 'O'),
#  ('Implemented', 'O'),
#  ('logistic', 'O'),
#  ('model', 'O'),
#  ('also', 'O'),
#  ('tableau', 'O'),
#  ('model', 'O'),
#  ('Analyzed', 'O'),
#  ('resale', 'O'),
#  ('insightful', 'O'),
#  ('analysis', 'O'),
#  ('Implemented', 'O'),
#  ('linear', 'O'),
#  ('model', 'O'),
#  ('Google', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Display', 'ORGANIZATION'),
#  ('Google', 'ORGANIZATION'),
#  ('Analysis', 'ORGANIZATION'),
#  ('Tools', 'ORGANIZATION'),
#  ('Tableau', 'ORGANIZATION'),
#  ('MSExcel', 'ORGANIZATION'),
#  ('Tools', 'ORGANIZATION'),
#  ('MSExcel', 'O'),
#  ('Oracle', 'O'),
#  ('Tableau', 'O'),
#  ('Salesforce', 'O'),
#  ('Tool', 'O'),
#  ('gplot', 'O'),
#  ('analyze', 'O'),
#  ('standardized', 'O'),
#  ('organization', 'O'),
#  ('optimization', 'O'),
#  ('minimized', 'O'),
#  ('analyzed', 'O'),
#  ('analyzing', 'O'),
#  ('maximize', 'O'),
#  ('Analyzed', 'O'),
#  ('18', 'O'),
#  ('88', 'O'),
#  ('EDUCATION', 'O'),
#  ('EXPERIENCE', 'O'),
#  ('California', 'ORGANIZATION'),
#  ('Created', 'ORGANIZATION'),
#  ('Created', 'ORGANIZATION'),
#  ('Cain', 'ORGANIZATION'),
#  ('Customer', 'ORGANIZATION'),
#  ('Contributed', 'ORGANIZATION'),
#  ('Conducted', 'ORGANIZATION'),
#  ('PROJECTS', 'ORGANIZATION'),
#  ('Campaign', 'O'),
#  ('CTR', 'O'),
#  ('TCR', 'O'),
#  ('CTR', 'O'),
#  ('Created', 'O'),
#  ('AIC', 'O'),
#  ('CERTIFICATIONS', 'O'),
#  ('TECHNICAL', 'O'),
#  ('Certifications', 'O'),
#  ('Certification', 'O'),
#  ('Car', 'O'),
#  ('wwwlinkedincominpranavgulghane', 'O'),
#  ('Pranav', 'O'),
#  ('Premdas', 'O'),
#  ('Gulghane', 'O'),
#  ('pranavpremdasgulghane', 'O'),
#  ('gmailcom', 'O'),
#  ('Texas', 'ORGANIZATION'),
#  ('Dallas', 'ORGANIZATION'),
#  ('Information', 'ORGANIZATION'),
#  ('Management', 'ORGANIZATION'),
#  ('Deans', 'ORGANIZATION'),
#  ('Scholarship', 'ORGANIZATION'),
#  ('Savitribai', 'ORGANIZATION'),
#  ('Telecommunication', 'ORGANIZATION'),
#  ('Data', 'ORGANIZATION'),
#  ('Analyst', 'ORGANIZATION'),
#  ('Sage', 'ORGANIZATION'),
#  ('Intacct', 'ORGANIZATION'),
#  ('California', 'ORGANIZATION'),
#  ('Analyst', 'O'),
#  ('Manipulate', 'O'),
#  ('analyze', 'O'),
#  ('large', 'O'),
#  ('data', 'O'),
#  ('Oracle', 'O'),
#  ('Database', 'O'),
#  ('data', 'O'),
#  ('forecasts', 'O'),
#  ('Managed', 'O'),
#  ('Salesforce', 'O'),
#  ('teams', 'O'),
#  ('day', 'O'),
#  ('sales', 'O'),
#  ('marketing', 'O'),
#  ('accounting', 'O'),
#  ('usage', 'O'),
#  ('data', 'O'),
#  ('create', 'O'),
#  ('maintain', 'O'),
#  ('standardized', 'O'),
#  ('dashboards', 'O'),
#  ('Tableau', 'O'),
#  ('management', 'O'),
#  ('Partnered', 'O'),
#  ('architecture', 'O'),
#  ('leads', 'O'),
#  ('address', 'O'),
#  ('data', 'O'),
#  ('rapidly', 'O'),
#  ('Automated', 'O'),
#  ('Tableau', 'O'),
#  ('Extract', 'O'),
#  ('via', 'O'),
#  ('calls', 'O'),
#  ('saving', 'O'),
#  ('Gathering', 'O'),
#  ('various', 'O'),
#  ('teams', 'O'),
#  ('ways', 'O'),
#  ('dashboard', 'O'),
#  ('Managed', 'O'),
#  ('access', 'O'),
#  ('Tableau', 'O'),
#  ('accordance', 'O'),
#  ('data', 'O'),
#  ('governance', 'O'),
#  ('Created', 'ORGANIZATION'),
#  ('Data', 'ORGANIZATION'),
#  ('Dictionary', 'ORGANIZATION'),
#  ('Metadata', 'ORGANIZATION'),
#  ('Data', 'ORGANIZATION'),
#  ('organization', 'O'),
#  ('statistically', 'O'),
#  ('significant', 'O'),
#  ('patterns', 'O'),
#  ('correlations', 'O'),
#  ('raised', 'O'),
#  ('team', 'O'),
#  ('logical', 'O'),
#  ('optimization', 'O'),
#  ('enhancing', 'O'),
#  ('overall', 'O'),
#  ('deliverable', 'O'),
#  ('Created', 'O'),
#  ('dashboards', 'O'),
#  ('data', 'O'),
#  ('associated', 'O'),
#  ('market', 'O'),
#  ('management', 'O'),
#  ('leaders', 'O'),
#  ('decisionmaking', 'O'),
#  ('data', 'O'),
#  ('cleaning', 'O'),
#  ('analyzed', 'O'),
#  ('Tableau', 'O'),
#  ('Jan', 'O'),
#  ('Cain', 'O'),
#  ('Data', 'O'),
#  ('Analyst', 'O'),
#  ('market', 'O'),
#  ('analysis', 'O'),
#  ('analyzing', 'O'),
#  ('overall', 'O'),
#  ('profitability', 'O'),
#  ('research', 'O'),
#  ('penetrating', 'O'),
#  ('market', 'O'),
#  ('data', 'O'),
#  ('Thirdparty', 'O'),
#  ('research', 'O'),
#  ('data', 'O'),
#  ('Based', 'O'),
#  ('Interpretation', 'O'),
#  ('Data', 'O'),
#  ('Tableau', 'O'),
#  ('data', 'O'),
#  ('tables', 'O'),
#  ('Important', 'O'),
#  ('marketing', 'O'),
#  ('sales', 'O'),
#  ('teams', 'O'),
#  ('understand', 'O'),
#  ('strategies', 'O'),
#  ('track', 'O'),
#  ('interplant', 'O'),
#  ('based', 'O'),
#  ('several', 'O'),
#  ('factors', 'O'),
#  ('manual', 'O'),
#  ('analyses', 'O'),
#  ('companies', 'O'),
#  ('comparing', 'O'),
#  ('market', 'O'),
#  ('marketing', 'O'),
#  ('strategies', 'O'),
#  ('Analysis', 'ORGANIZATION'),
#  ('Marketing', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('Campaign', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('strategy', 'O'),
#  ('implementation', 'O'),
#  ('campaign', 'O'),
#  ('maximize', 'O'),
#  ('brand', 'O'),
#  ('awareness', 'O'),
#  ('create', 'O'),
#  ('statistically', 'O'),
#  ('page', 'O'),
#  ('Analytics', 'O'),
#  ('track', 'O'),
#  ('searched', 'O'),
#  ('data', 'O'),
#  ('recommendations', 'O'),
#  ('sale', 'O'),
#  ('Analysis', 'O'),
#  ('Hadoop', 'O'),
#  ('Tableau', 'O'),
#  ('Created', 'O'),
#  ('Hadoop', 'O'),
#  ('calculate', 'O'),
#  ('factors', 'O'),
#  ('created', 'O'),
#  ('loaded', 'O'),
#  ('dataset', 'O'),
#  ('tables', 'O'),
#  ('also', 'O'),
#  ('created', 'O'),
#  ('interactive', 'O'),
#  ('dashboard', 'O'),
#  ('tableau', 'O'),
#  ('based', 'O'),
#  ('geographic', 'O'),
#  ('area', 'O'),
#  ('Analyzed', 'O'),
#  ('dataset', 'O'),
#  ('States', 'O'),
#  ('car', 'O'),
#  ('resale', 'O'),
#  ('achieved', 'O'),
#  ('analysis', 'O'),
#  ('features', 'O'),
#  ('linear', 'O'),
#  ('feature', 'O'),
#  ('extraction', 'O'),
#  ('backward', 'O'),
#  ('Certifications', 'ORGANIZATION'),
#  ('Analytics', 'ORGANIZATION'),
#  ('Display', 'ORGANIZATION'),
#  ('Search', 'ORGANIZATION'),
#  ('Certification', 'ORGANIZATION'),
#  ('Analysis', 'ORGANIZATION'),
#  ('Tableau', 'ORGANIZATION'),
#  ('Programming', 'ORGANIZATION'),
#  ('Java', 'ORGANIZATION'),
#  ('Software', 'ORGANIZATION'),
#  ('Oracle', 'ORGANIZATION'),
#  ('Database', 'ORGANIZATION'),
#  ('Tableau', 'ORGANIZATION'),
#  ('Salesforce', 'ORGANIZATION'),
#  ('Databases', 'ORGANIZATION'),
#  ('Car', 'O'),
#  ('forecast', 'O'),
#  ('May', 'O'),
#  ('EXPERIENCE', 'O'),
#  ('wwwlinkedincominpranavgulghane', 'O'),
#  ('Premdas', 'O'),
#  ('Gulghane', 'O'),
#  ('pranavpremdasgulghane', 'O'),
#  ('The', 'ORGANIZATION'),
#  ('University', 'ORGANIZATION'),
#  ('Texas', 'ORGANIZATION'),
#  ('Technology', 'ORGANIZATION'),
#  ('Management', 'ORGANIZATION'),
#  ('December', 'O'),
#  ('Deans', 'O'),
#  ('Excellence', 'O'),
#  ('Recipient', 'O'),
#  ('June', 'O'),
#  ('Phule', 'O'),
#  ('Pune', 'ORGANIZATION'),
#  ('University', 'ORGANIZATION'),
#  ('Pune', 'ORGANIZATION'),
#  ('Electronics', 'ORGANIZATION'),
#  ('Telecommunication', 'ORGANIZATION'),
#  ('Engineering', 'ORGANIZATION'),
#  ('Accenture', 'ORGANIZATION'),
#  ('Sage', 'ORGANIZATION'),
#  ('June', 'O'),
#  ('Present', 'O'),
#  ('Business', 'O'),
#  ('Intelligence', 'O'),
#  ('Intern', 'O'),
#  ('Manipulate', 'O'),
#  ('analyze', 'O'),
#  ('large', 'O'),
#  ('sets', 'O'),
#  ...]

# %%
def name_person():
    temp_person = []
    for tuple_ele in tagged:
        if "PERSON" in tuple_ele[1]:
            temp_person.append(tuple_ele[0])
    ## loop through the original words so we can extract from the first words and get the first PERSON
    for word in words:
        if word in temp_person:
            print(word)

# %%
name_person()
# Out:
# Python
# Hadoop
# Hadoop
# Python
