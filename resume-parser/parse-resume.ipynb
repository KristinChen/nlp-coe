# %% [markdown]
# # Resume Parser Project

# %% [markdown]
# ### Importing Libraries

# %%
import pdfminer
from pdfminer.high_level import extract_text
import glob
import nltk
from string import punctuation
from nltk.corpus import stopwords
import re
from nltk.tag import pos_tag
from names_dataset import NameDataset
nd = NameDataset()
import spacy #numpy needs to be <1.20
nlp = spacy.load("en_core_web_sm")
import os

# def read_file (in: path, out: text)
# def preprocess_text (in: ordinary_text, out: cleaned_text)
# def get_info (in: text, out: {resume_idx1:{name: 'kristin chen'}, {email: 'helloworld@gamil.com'}})
## def: get_name (in: text, out: {name: }
## def: get_degree_info (in: text: out :{degree1: {name: degree_name, level: phd, graduation_date: 01/02/2022}}
## def: get_email (in: text, out: {email: }}
## def: get_phone_number

# %% [markdown]
# ### Extended list of last names and reserved keywords for Universities

# %%
# -------------------------------------------------------------------------
us_names = nd.get_top_names(n=1000, gender='Male', country_alpha2='US')['US']['M']
indian_last_names = ["Acharya", "Agarwal", "Khatri", "Ahuja", "Anand", "Laghari", "Patel",

                     "Reddy", "Bakshi", "Anthony", "Babu", "Arya", "Balakrishnan", "Banerjee", "Burman", "Bhatt",
                     "Basu", "Bedi", "Varma", "Dara", "Dalal", "Chowdhury",
                     "Chabra", "Chadha", "Chakrabarti", "Chawla", "Ahluwalia", "Amin", "Apte", "Datta", "Deol",
                     "Deshpande", "Dewan", "Lal", "Kohli", "Mangal", "Malhotra", "Jha",
                     "Joshi", "Kapadia", "Iyer", "Jain", "Khanna", "Grover", "Kaur", "Kashyap", "Gokhale", "Ghosh",
                     "Garg", "Dhar", "Gandhi", "Ganguly", "Gupta", "Das", "Chopra", "Dhawan",
                     "Dixit", "Dubey", "Haldar", "Kapoor", "Khurana", "Kulkarni", "Madan", "Bajwa", "Bhasin", "Chandra",
                     "Chauhan", "Deshmukh", "Dayal", "Dhillon", "Goswami", "Goel", "Mallick",
                     "Mahajan", "Kumar", "Mani", "Gill", "Mannan", "Biswas", "Batra", "Bawa", "Mehta", "Mukherjee",
                     "Saxena", "Zacharia", "Shah", "Ray", "Rao", "Purohit", "Parekh", "Thakur", "Singh", "Sharma",
                     "Seth", "Sachdev", "Ranganathan", "Puri", "Pandey", "Naidu", "Modi"]

chinese_last_names = ["Li", "Wang", "Zhang", "Liu", "Chen", "Yang", "Zhao", "Huang", "Zhou",

                      "Wu", "Xu", "Sun", "Hu", "Zhu", "Gao", "Lin", "He", "Guo", "Ma", "Luo", "Liang",

                      "Song", "Zheng", "Xie", "Han", "Tang", "Feng", "Yu", "Dong", "Xiao", "Cheng",

                      "Cao", "Yuan", "Deng", "Xu", "Fu", "Shen", "Zeng", "Peng", "Lu", "Su", "Lu", "Jiang", "Cai",
                      "Jia", "Ding", "Wei", "Xue", "Ye", "Yan",

                      "Yu", "Pan", "Du", "Dai", "Xia", "Zhong", "Wang", "Tian", "Ren", "Jiang", "Fan", "Fang", "Shi",
                      "Yao", "Tan", "Sheng", "Zou", "Xiong", "Jin", "Lu", "Hao", "Kong", "Bai", "Cui",

                      "Kang", "Mao", "Qio", "Qin", "Jiang", "Shu", "Shi", "Gu", "Hou", "Shao", "Meng", "Long", "Wan",
                      "Duan", "Zhang", "Qian", "Tang", "Yin", "Li", "Yi", "Chang", "Wu",

                      "Qiao", "He", "Lao", "Gong", "Wen"]

chinese_last_names = [chinese_last_name.lower() for chinese_last_name in chinese_last_names]
indian_last_names = [indian_last_name.lower() for indian_last_name in indian_last_names]

# -----------------------------------------------------------------
RESERVED_WORDS = [
    'school',
    'college',
    'univers',
    'academy',
    'faculty',
    'institute',
    'faculdades',
    'Schola',
    'schule',
    'lise',
    'lyceum',
    'lycee',
    'polytechnic',
    'kolej',
    'ünivers',
    'okul',
    'University'
]

# %% [markdown]
# ### Read files

# %%
def read_file(path):
    # with pdfplumber.open(path) as pdf:
    #     first_page = pdf.pages[0] # Question: why first page?
    #     txt1 = first_page.extract_text()

    txt = extract_text(path, codec='utf-8')
    return txt

# %% [markdown]
# ### Preprocess Text

# %%
'''need to be happened every steps'''
def preprocess_text(txt):
    # verify type of input
    if not isinstance(txt, str):
        raise TypeError('Work with String Only')
    # verify len(text)
    if len(txt) < 1:
        raise ValueError('Work with nonempty String Only')
    #tokenize
    words = nltk.word_tokenize(txt)

    #remove stopwords and punctuations
    stopwords_set = set(stopwords.words('english'))
    simple_strings = [word for word in words if word not in stopwords_set if word not in punctuation]

    #remove unwanted characters
    res = [re.sub(r'[^\w\s]', '', word) for word in simple_strings]
    res1 = [re.sub(r'^abc(.*?)=[A-Z0-9]+(.*)', r'\1\2', word) for word in res]
    res2 = [str(res) for res in res1]

    res3 = [re.sub(r'/^[A-Za-z]+$/', '', res) for res in res2]
    res3 = [res.replace("ï", "i") if "ï" in res else res for res in res3]
    res3 = [re.sub('\d', '', res) for res in res3]
    res3 = [res.encode('ascii', "ignore").decode() for res in res3]

    return list(filter(None, res3)) #remove empty string from list #return tokens_txt

# %% [markdown]
# ### Extracting `names` function

# %%
def get_name(sentence_txt, tokens_txt): #-> list of person names
    temp_person = []
    nltk_tagged = pos_tag(tokens_txt[:11])
    for k in range(10):
        if nltk_tagged[k][1] == 'NNP' and nltk_tagged[k + 1][1] == 'NNP':
            nltk_name = nltk_tagged[k][0] + ' ' + nltk_tagged[k + 1][0]
            temp_person.append(nltk_name)
            if len(temp_person) > 0:# Comment: stop as long as you got the nltk_name
                return temp_person

        # for chunk in doc.noun_chunks:
        #     print(chunk.text) #Comment: maybe try noun chunks to get the name

        if k > 1:
            if (tokens_txt[k].lower() in indian_last_names) or (tokens_txt[k].lower() in chinese_last_names):
                j = k - 1
                return([tokens_txt[j] + " " + tokens_txt[k]]) #Comment: what if kristin (jiating) chen?

    tagged = nlp(sentence_txt[0:200]) #Comment: assume names exist in the top section
    for word in tagged.ents:
        if word.label_ == "PERSON":
            temp_person.append(word.text)
        return temp_person

# %% [markdown]
# ### Extracting `education` , `phone number`, `email`, `phd degree`, `master degree` and `bachelor degree`

# %%
# Can later break down these functions into separate cells if required
def extract_education(txt): # Comment: this is not solid
    edu=set()
    p = re.compile('(EDUCATION)?\n?(.*?),\s+(.*?),(.*?)')
    for m in re.finditer(p, txt):

        for word in RESERVED_WORDS:
            if word in m.group(2).lower():
                edu.add(m.group(2))
    return edu

# -----------------------------
def extract_phone_number(txt):
    PHONE_REG = re.compile(r'[\+\(]?[1-9][0-9 .\-\(\)]{8,}[0-9]')
    phone = re.findall(PHONE_REG, txt)

    if phone:
        number = ''.join(phone[0])

        if txt.find(number) >= 0 and len(number) < 16:
            return number
    return None

# ---------------------------- -
def extract_email(txt):
    EMAIL_REG = re.compile(r'[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+')
    return re.findall(EMAIL_REG, txt)

# -----------------------------------
def extract_phd_degree(txt):
    phd_set = set()
    p = re.compile('(Ph\.D).*,|(Ph\.D).*\\n')
    for m in re.finditer(p, txt):
        candidate_txt = m.group().split(',')[0]
        phd_set.add(' '.join(candidate_txt.split()))
    return phd_set

# ------------------------------------
def extract_master_degree(txt):
    masters_set = set()
    p = re.compile('(Master|MS|M\.S\.|MA|M\.A\.|MBA|M\.S\.E|M\.tech).*,|(Master|MS|M\.S\.|MA|M\.A\.|MBA|M\.S\.E|M\.tech).*\\n')  # greedy
    for m in re.finditer(p, txt):
        candidate_txt = m.group().split(',')[0] #Comment: to avoid getting 'MS Excel MS word'....
        if 'Master' in candidate_txt:
            return ' '.join(candidate_txt.split()) #immediate return master
        else:
            masters_set.add(' '.join(candidate_txt.split()))
    return masters_set


# ---------------------------------
def extract_bachelor_degree(txt):
    bachelors_set = set()
    p = re.compile('(Bachelor|BS|B\.S\.|BA|B\.A\.|B\.S\.E|B\.tech).*,|(Bachelor|BS|B\.S\.|BA|B\.A\.|B\.S\.E|B\.tech).*\\n')  # greedy
    for m in re.finditer(p, txt):
        candidate_txt = m.group().split(',')[0] #MS Excel MS word....
        if 'Bachelor' in candidate_txt:
            return ' '.join(candidate_txt.split()) #immediate return master
        else:
            bachelors_set.add(' '.join(candidate_txt.split()))
    return bachelors_set

# %% [markdown]
# ### Extracting `schools for all degrees`

# %%
def extract_phd_school(txt):
    p = re.compile('(?i)(school|college|univers|academy|faculty|institute|faculdades|Schola|schule|lise|lyceum|lycee|polytechnic|kolej|ünivers|okul|University)(.|\n)*(Ph.D.|PhD|PhD.)')
    for m in re.finditer(p, txt):
        return m.group(0).split("\n")[0]
    
def extract_ms_school(txt):
    p = re.compile('(?i)(school|college|univers|academy|faculty|institute|faculdades|Schola|schule|lise|lyceum|lycee|polytechnic|kolej|ünivers|okul|University)(.|\n)*(M.S.|M.S|M.Sc.|MS|Masters|Master\'s|Master)')
    for m in re.finditer(p, txt):
        return m.group(0).split("\n")[0]
    
## Using regex for finding university nearest to Bachelor's degree   
def extract_bach_school(txt):
    p = re.compile('(?i)(school|college|academy|faculty|institute|faculdades|Schola|schule|lise|lyceum|lycee|polytechnic|kolej|ünivers|okul|University)(?:(?!(?i)(school|college|academy|faculty|institute|faculdades|Schola|schule|lise|lyceum|lycee|polytechnic|kolej|ünivers|okul|University)|(Bachelors|B.tech|Bachelor\'s|B.A.|BS|B.Sc.|B.S|B.S.))[\s\S])*(Bachelors|B.tech|Bachelor\'s|B.A.|BS|B.Sc.|B.S|B.S.)')
    for m in re.finditer(p, txt):
        return m.group(0).split("\n")[0]

# %% [markdown]
# ### Extracting `graduation dates for all degrees`

# %%
def extract_phd_date(txt):
    dates=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
    year ="(\d{4})"
    month = "((?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Sept|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?))"

    for line in txt.split('\n'):
        if len(line.split())==0:
            continue
        for token in line.split():
            ## Check for line containing these tokens
            if token.lower() in ["ph.d.","phd","phd."]:
#                 print(line)
                ## check for dates in these lines
                if re.findall(year,line):
                                 
                    return(re.findall(year,line)[-1] + ' ' + re.findall(month,line)[-1])
                
def extract_masters_date(txt):
    dates=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
    year ="(\d{4})"
    month = "((?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Sept|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?))"

    for line in txt.split('\n'):
        if len(line.split())==0:
            continue
        for token in line.split():
            ## Check for line containing these tokens
            if token.lower() in ['ms',"master's",'master','m.s','master','m.s.','m.sc.','masters']:
#                 print(line)
                ## check for dates in these lines
                if re.findall(year,line):
                                 
                    return(re.findall(year,line)[-1] + ' ' + re.findall(month,line)[-1])
                
def extract_bach_date(txt):
    dates=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
    year ="(\d{4})"
    month = "((?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Sept|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?))"

    for line in txt.split('\n'):
        if len(line.split())==0:
            continue
        for token in line.split():
            ## Check for line containing these tokens
            if token.lower() in ["bachelors","b.tech","bachelor's","b.a.","bs","b.sc.","b.s","b.s."]:
#                 print(line)
                ## check for dates in these lines
                if re.findall(year,line):
                                 
                    return(re.findall(year,line)[-1] + ' ' + re.findall(month,line)[-1])

# %% [markdown]
# ### Main functions `get_info` and `parse_resume` to call other functions

# %%
# --------- aggregate -----------------------------
def get_info(txt):
    tokens_txt = preprocess_text(txt)
    name = get_name(txt, tokens_txt)
    education = extract_education(txt)
    phone_number = extract_phone_number(txt)
    email = extract_email(txt)
    master = extract_master_degree(txt)
    bachelor = extract_bachelor_degree(txt)
    phd = extract_phd_degree(txt)
    phd_school = extract_phd_school(txt)
    ms_school = extract_ms_school(txt)
    bach_school = extract_bach_school(txt)
    phd_grad_date = extract_phd_date(txt)
    ms_grad_date = extract_masters_date(txt)
    bach_grad_date = extract_bach_date(txt)
    return {
        'name' : name,
        'phone_number' : phone_number,
        'email' : email,
        'master_degree' : master,
        'bachelor_degree': bachelor,
        'phd_degree' : phd,
        'phd_school' : phd_school,
        'ms_school' : ms_school,
        'bach_school' : bach_school,
        'phd_grad_date' : phd_grad_date,
        'ms_grad_date' : ms_grad_date,
        'bach_grad_date' : bach_grad_date
    }

def parse_resume(path):
    index = os.path.basename(path)
    print(index)
    try:
        raw_txt = read_file(path)
    except pdfminer.pdfparser.PDFSyntaxError:
        return_dict = {'index': index,
                   'name': None,
                   'phone_number': None,
                   'email': None,
                   'master_degree': None,
                   'bachelor_degree': None,
                   'phd_degree': None,
                   'phd_school': None,
                   'ms_school': None,
                   'bach_school': None,
                   'phd_grad_date' : None,
                   'ms_grad_date' : None,
                   'bach_grad_date' : None
    }
        return return_dict

    if not isinstance(raw_txt, str):
        return_dict = {   'index' : index,
                          'name': None,
                          'phone_number': None,
                          'email': None,
                          'master_degree': None,
                          'bachelor_degree': None,
                          'phd_degree': None,
                          'phd_school': None,
                          'ms_school': None,
                          'bach_school': None,
                          'phd_grad_date' : None,
                          'ms_grad_date' : None,
                          'bach_grad_date' : None}
        return return_dict
    elif len(raw_txt) < 8:
        return_dict = {   'index' : index,
                          'name': None,
                          'phone_number': None,
                          'email': None,
                          'master_degree': None,
                          'bachelor_degree': None,
                          'phd_degree': None,
                          'phd_school': None,
                          'ms_school': None,
                          'bach_school': None,
                          'phd_grad_date' : None,
                          'ms_grad_date' : None,
                          'bach_grad_date' : None}
    else:
        info_dict = get_info(raw_txt)
        return_dict = {**{'index': index}, **info_dict}
        return return_dict

# execution ---------------------
folder = glob.glob(r"C:/Users/rtd91/Data/resume_samples/*")

folder

file_path = folder[3]
for file_path in folder:
    print(parse_resume(file_path))
# Out:
# 721091408_phonescreening.pdf
# C:\Users\rtd91\anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: Flags not at the start of the expression '(?i)(school|college|' (truncated)
#   del sys.path[0]
# {'index': '721091408_phonescreening.pdf', 'name': ['Karthik Ramanarayana'], 'phone_number': '(410)-292-1151', 'email': ['karthikr2194@gmail.com'], 'master_degree': 'Master of Professional Studies in Data Science', 'bachelor_degree': 'Bachelor of Engineering in Electronics and Communication Engineering', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Maryland, Baltimore County, Baltimore, Maryland  ', 'bach_school': 'Institute of Technology, Bangalore, India ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821101104_phonescreening.pdf
# {'index': '821101104_phonescreening.pdf', 'name': ['HARSH PUNDIR'], 'phone_number': None, 'email': ['hpundir@umd.edu'], 'master_degree': 'Master of Science in Business Analytics', 'bachelor_degree': 'Bachelor of Technology in Mechanical Engineering', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'School of Business, University of Maryland, College Park, MD ', 'bach_school': 'School of Bus', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821101136_phonescreening.pdf
# {'index': '821101136_phonescreening.pdf', 'name': ['TIRTH PATEL'], 'phone_number': '469-370-9437', 'email': ['tirth2410@gmail.com'], 'master_degree': 'Master of Science', 'bachelor_degree': 'Bachelor of Technology', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Texas at Dallas, Dallas, TX ', 'bach_school': 'University of Texas at Dallas, Dallas, TX ', 'phd_grad_date': None, 'ms_grad_date': '2021 May', 'bach_grad_date': None}
# 821110120.pdf
# {'index': '821110120.pdf', 'name': ['Akanksha Bapna'], 'phone_number': None, 'email': [], 'master_degree': 'Master of Marketing Analytics', 'bachelor_degree': 'Bachelors in Technology', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Maryland, Robert H. Smith School of Business (3.5)', 'bach_school': 'School of Bus', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821110440_Mythri.pdf
# {'index': '821110440_Mythri.pdf', 'name': ['Mythri Partha'], 'phone_number': '(281) 725-7080', 'email': ['mythripartha8@gmail.com'], 'master_degree': set(), 'bachelor_degree': {'B.S. Chemistry - Minor: Mathematics'}, 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Houston, Houston, TX ', 'bach_school': 'University of Houston, Houston, TX ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821110445_Qizhe.pdf
# {'index': '821110445_Qizhe.pdf', 'name': ['Qizhe Wang'], 'phone_number': None, 'email': ['ziyaotingyu@gmail.com'], 'master_degree': 'Master of Science in Statistics |GPA: 3.88/4.0', 'bachelor_degree': 'Bachelor of Science in Statistics (Minor in Computer Science) Sep 2016 - Dec 2019', 'phd_degree': set(), 'phd_school': 'University of Delaware                Master of Science in Statistics |GPA: 3.88/4.0 ', 'ms_school': 'University of Delaware                Master of Science in Statistics |GPA: 3.88/4.0 ', 'bach_school': 'University of Delaware                Bachelor of Science in Statistics (Minor in Computer Science)                        Sep 2016 - Dec 2019                                                  ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821110447_rachan.pdf
# {'index': '821110447_rachan.pdf', 'name': ['RACHAN VAMSI'], 'phone_number': '(475) 685 0166', 'email': ['rachan_vamsi.bhooshi@uconn.edu'], 'master_degree': 'Master of Science in Business Analytics and Project Management December 2021', 'bachelor_degree': 'Bachelor of Technology in Mechanical Engineering May 2019', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Connecticut and Eversource where I supported   ', 'bach_school': 'University of Connecticut and Eversource where I supported   ', 'phd_grad_date': None, 'ms_grad_date': '2021 December', 'bach_grad_date': None}
# 821110448_RAGHUVEERA.pdf
# {'index': '821110448_RAGHUVEERA.pdf', 'name': ['RAGHUVEERA KARTHIK'], 'phone_number': '240-713-8296', 'email': ['rmadireddy1@student.gsu.edu'], 'master_degree': {'MADIREDDY', 'MS-DB database to MySQL database for 5 applications.', 'MAPE of over 2000 SKUs from 25% to 18% over a 6 month period.', 'MAPE using tree'}, 'bachelor_degree': 'Bachelor of Technology', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University', 'bach_school': 'Institute of Technology', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821110464_Saida.pdf
# {'index': '821110464_Saida.pdf', 'name': ['SAIDA MUKTAR'], 'phone_number': '443-833-6344', 'email': ['saidam1@umbc.edu'], 'master_degree': {'MATLAB to test the models by fitting date from blocking nuclear efflux with Leptomycin', 'MATLAB', 'MATLAB to find parameters and fit parameters', 'MS in Data Science Graduation: August 2021', 'MS or PhD degree i n system e ngineering or deci sion theory', 'MARYLAND BALTIMORE', 'MS degree in statistics', 'MARYLAND BALTIMORE COUNTY'}, 'bachelor_degree': {'BALTIMORE', 'BS in Mathematics Graduation: December 2019', 'BALTIMORE COUNTY', 'BS degree in statistics', 'BS degree'}, 'phd_degree': set(), 'phd_school': 'UNIVERSITY OF MARYLAND BALTIMORE COUNTY      ', 'ms_school': 'UNIVERSITY OF MARYLAND BALTIMORE COUNTY      ', 'bach_school': 'UNIVERSITY OF MARYLAND BALTIMORE  ', 'phd_grad_date': None, 'ms_grad_date': '2021 August', 'bach_grad_date': '2019 December'}
# 821110509_Akash.pdf
# {'index': '821110509_Akash.pdf', 'name': ['Allentown PA'], 'phone_number': '+1 4845387112', 'email': ['adp178@scarletmail.rutgers.edu'], 'master_degree': 'Master’s in data science', 'bachelor_degree': 'Bachelor of Technology in Chemical Engineering; Cumulative GPA: 8.57/10.0', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of New Jersey – New Brunswick, NJ, USA ', 'bach_school': 'University Nadiad India   ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821110510_AKSHARA.pdf
# {'index': '821110510_AKSHARA.pdf', 'name': ['AKSHARA ARCOT'], 'phone_number': None, 'email': ['akshara@ou.edu'], 'master_degree': 'Master of Science in Data Science and Analytics', 'bachelor_degree': 'Bachelor of Technology in Computer Science', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Oklahoma', 'bach_school': 'Institute of Technology and Science (GNITS)', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821110511_Alexandra.pdf
# {'index': '821110511_Alexandra.pdf', 'name': ['Alexandra Manetas'], 'phone_number': '630.818.6275', 'email': ['manetas.alexandra@gmail.com'], 'master_degree': 'Masters of Science', 'bachelor_degree': 'Bachelor of Science', 'phd_degree': set(), 'phd_school': None, 'ms_school': None, 'bach_school': 'Institutes and Centers Administration ', 'phd_grad_date': None, 'ms_grad_date': '2021 August', 'bach_grad_date': None}
# 821110527_.pdf
# {'index': '821110527_.pdf', 'name': ['Pranav Premdas'], 'phone_number': '+1-4695140740', 'email': ['pranavpremdasgulghane@gmail.com'], 'master_degree': {'M.S.', 'MS-Access', 'MS-Excel'}, 'bachelor_degree': set(), 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Texas at Dallas ', 'bach_school': 'University, Pune ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821110528_Wanting.pdf
# {'index': '821110528_Wanting.pdf', 'name': ['Lu Berkeley'], 'phone_number': '(559) 387-0880', 'email': ['luwinnie12@gmail.com'], 'master_degree': set(), 'bachelor_degree': 'Bachelor of Arts in Applied Mathematics and Data Science July 2019 - December 2021', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of California, Berkeley', 'bach_school': 'University of California, Berkeley', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821111539_manaswini.pdf
# {'index': '821111539_manaswini.pdf', 'name': ['Northeastern University'], 'phone_number': '(617) 818-4953', 'email': ['nagaraj.m@northeastern.edu'], 'master_degree': 'Master of Science in Data Science', 'bachelor_degree': 'Bachelor of Technology in Computer Science Engineering', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University, Khoury College of Computer Sciences, Boston, MA                                                  Aug 2019 - Dec 2021                                                                                 ', 'bach_school': 'College of Computer Sciences, Bos', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821112919_mohit.pdf
# {'index': '821112919_mohit.pdf', 'name': ['MOHIT MANJARIA'], 'phone_number': '+18572077337', 'email': ['mohitmanjaria55333@gmail.com'], 'master_degree': 'Master’s in Data Analytics (concentration in statistical modelling)', 'bachelor_degree': 'Bachelors of Management Studies (concentration in marketing)', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'UNIVERSITY  ', 'bach_school': 'UNIVERSITY  ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821112928_yechen.pdf
# {'index': '821112928_yechen.pdf', 'name': ['Yuchen Xie'], 'phone_number': '949-413-2863', 'email': ['yuchen724@ucla.edu'], 'master_degree': {'MATLAB | Mathematica | JavaScript | R | SAS | Stata | SQL | C++ | HTML5 | PHP | CSS3', 'MATLAB.'}, 'bachelor_degree': {'BA; applied the exponential smoothing algorithm and the Holt’s two-parameter', 'B.S. in Applied Mathematics (Specialization in Computing)', 'B.S. in Mathematics | Cum GPA: 3.867/4.0'}, 'phd_degree': set(), 'phd_school': 'University of California, Los Angeles (UCLA), CA', 'ms_school': 'University of California, Los Angeles (UCLA), CA', 'bach_school': 'University of California, Los Angeles (UCLA), CA', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821122313_Dimple.pdf
# {'index': '821122313_Dimple.pdf', 'name': ['Mobile Dimple'], 'phone_number': None, 'email': ['dimple8997@gmail.com'], 'master_degree': 'Master of Science in Computer Science', 'bachelor_degree': 'Bachelor of Engineering in Electronics and Computers', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'Institute of Technology', 'bach_school': 'College', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821122315_Indupriya.pdf
# {'index': '821122315_Indupriya.pdf', 'name': ['Indupriya Kompi'], 'phone_number': None, 'email': ['indupriyakompi@gmail.com'], 'master_degree': 'Master of Science Information Systems | 3.54/4 GPA', 'bachelor_degree': 'Bachelor of Engineering Electronics and Communications | 3.0/4', 'phd_degree': set(), 'phd_school': None, 'ms_school': None, 'bach_school': 'University, Bos', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 821122316_James.pdf
# {'index': '821122316_James.pdf', 'name': ['James Renier'], 'phone_number': '(706) 305-6369', 'email': ['james.domingo@gatech.edu'], 'master_degree': 'Master of Science in Analytics (Current GPA: 4.0)', 'bachelor_degree': 'Bachelor of Science in Industrial Engineering', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'Institute of Technology ', 'bach_school': 'Institute of Technology ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 822010605_anya.pdf
# {'index': '822010605_anya.pdf', 'name': ['ANYA PATEL'], 'phone_number': '805 453 1532', 'email': ['anyampatel@gmail.com'], 'master_degree': {'MARY', 'MATLAB', 'MACHINE LEARNING / DATA SCIENCE INTERN'}, 'bachelor_degree': {'B.S.'}, 'phd_degree': set(), 'phd_school': None, 'ms_school': None, 'bach_school': None, 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 822010628_ryan.pdf
# {'index': '822010628_ryan.pdf', 'name': ['Ryan Martin'], 'phone_number': '(910) 547-7027', 'email': ['rgoodwin1997@gmail.com'], 'master_degree': {'M.S. Data Science'}, 'bachelor_degree': {'B.S. Applied Physics'}, 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of North Carolina Wilmington ', 'bach_school': 'University of North Carolina Wilmington ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 822011416_Mayank.pdf
# {'index': '822011416_Mayank.pdf', 'name': ['Mayank Dubey'], 'phone_number': None, 'email': ['mayankdubey1996@gmail.com'], 'master_degree': {'MARY', 'MS in'}, 'bachelor_degree': 'Bachelor of Engineering', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University, Fairfax VA                                                                                                                                                     ', 'bach_school': 'University ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# 822011417_Abhinay.pdf
# {'index': '822011417_Abhinay.pdf', 'name': ['ABHINAY NAGULAPALLI'], 'phone_number': '(571) 752-8188', 'email': ['abhinay.nagulapalli98@gmail.com'], 'master_degree': 'Master of Professional Studies in Data Science', 'bachelor_degree': 'Bachelor of Engineering in Information Technology', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Maryland, Baltimore County, Baltimore, MD ', 'bach_school': 'University, India                                                                                                ', 'phd_grad_date': None, 'ms_grad_date': '2021 December', 'bach_grad_date': None}
# 822013101_Noah.pdf
# {'index': '822013101_Noah.pdf', 'name': ['Noah Mattheis'], 'phone_number': '240.490.0733', 'email': ['noahwkm@gmail.com'], 'master_degree': {'MATLAB'}, 'bachelor_degree': {'BS in Mathematics'}, 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Maryland | College Park, MD', 'bach_school': 'College Park, MD', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AbhilashRajaram.pdf
# {'index': 'AbhilashRajaram.pdf', 'name': ['Abhilash Rajaram'], 'phone_number': '7162929981', 'email': ['rajaram2@buffalo.edu'], 'master_degree': 'Masters degree. Three years of work experience with expertise in statistical analysis', 'bachelor_degree': 'Bachelors in Computer Science and Engineering; GPA: 3.5/4.0', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University at Buffalo, The State University of New York', 'bach_school': 'University of New York', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AdamDinser.pdf
# {'index': 'AdamDinser.pdf', 'name': ['Adam Dinser'], 'phone_number': '(720) 560-3886', 'email': ['adam.m.dinser@gmail.com'], 'master_degree': {'MATPLOT', 'MARKOV MODELS (RANDOM WALKS', 'MS', 'MACHINE LEARNING : DECISION TREE', 'MATRICES', 'MATHEMATICAL IDEAS', 'MAXIMIZATION', 'MS)'}, 'bachelor_degree': {'BAYESIAN NETWORKS', 'BSTRACT ALGEBRA : SYMMETRIES', 'BA', 'BASKET ANALYSIS'}, 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University Of Colorado Boulder', 'bach_school': 'Academy', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AdeolaAdesoba.pdf
# {'index': 'AdeolaAdesoba.pdf', 'name': ['ADEOLA ADESOBA'], 'phone_number': '(423) 741-5160', 'email': ['atadesoba@gmail.com'], 'master_degree': {'MAD Information framework for Arkansas Arts Council', 'MS Information Science (Major: Information Quality |Minor: Data Science) - GPA: 3.90'}, 'bachelor_degree': 'Bachelor of Science in Statistics | GPA: 3.19/4', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Arkansas at Little Rock, Little Rock, Arkansas, USA ', 'bach_school': 'University of Arkansas at Little Rock, Little Rock, Arkansas, USA ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AjayPrasathManoharan.pdf
# {'index': 'AjayPrasathManoharan.pdf', 'name': ['AJAY PRASATH'], 'phone_number': None, 'email': ['amanoha3@ncsu.edu'], 'master_degree': 'Master of Industrial Engineering Aug 2019 – May 2021', 'bachelor_degree': 'Bachelor of Engineering in Mechanical Engineering', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University                                                                                                                                                GPA: 3.6/4 ', 'bach_school': 'University                                                                                                                                                                       GPA: 8.73/10 ', 'phd_grad_date': None, 'ms_grad_date': '2021 May', 'bach_grad_date': None}
# AkshayKajale.pdf
# {'index': 'AkshayKajale.pdf', 'name': ['Akshay Kajale'], 'phone_number': '+1 669-278-8855', 'email': ['akshay.kajale@sjsu.edu'], 'master_degree': 'Master of Science in Computer Science', 'bachelor_degree': 'Bachelor of Engineering in Computer Engineering', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University, CA (GPA:3.59/4.0) ', 'bach_school': 'University of Pune, India (GPA: 3.3/4.0)   ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# Alexander Friend.pdf
# {'index': 'Alexander Friend.pdf', 'name': ['ALEXANDER FRIEND'], 'phone_number': '(949) 441-8713', 'email': ['afriend6874@gmail.com'], 'master_degree': {'MATLAB'}, 'bachelor_degree': 'Bachelor of Science in Data Science', 'phd_degree': set(), 'phd_school': 'UNIVERSITY OF CALIFORNIA, SAN DIEGO | San Diego, CA | 2017 - 2021 ', 'ms_school': 'UNIVERSITY OF CALIFORNIA, SAN DIEGO | San Diego, CA | 2017 - 2021 ', 'bach_school': 'UNIVERSITY OF CALIFORNIA, SAN DIEGO | San Diego, CA | 2017 - 2021 ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AmarJha.pdf
# {'index': 'AmarJha.pdf', 'name': ['Amar Nath'], 'phone_number': '(213) 462-8044', 'email': ['jhaa@usc.edu'], 'master_degree': 'Master’s in Applied Data Science', 'bachelor_degree': set(), 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Southern California, Los Angeles, CA ', 'bach_school': 'University of Southern California, Los Angeles, CA ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AmolAgrawal.pdf
# {'index': 'AmolAgrawal.pdf', 'name': ['Amol Agrawal'], 'phone_number': None, 'email': ['amolagrawal05@gmail.com'], 'master_degree': 'Masters in Machine Learning.', 'bachelor_degree': 'Bachelors of Science in Computer Science', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'Institute of Technology', 'bach_school': 'College of Engineering', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AndrewLin.pdf
# {'index': 'AndrewLin.pdf', 'name': ['Andrew Yuchen'], 'phone_number': '678-707-0060', 'email': ['andrew.linlyc@gmail.com'], 'master_degree': 'Master of Science in Analytics MSA', 'bachelor_degree': 'Bachelor of Management - Finance', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'INSTITUTE OF TECHNOLOGY  ', 'bach_school': 'UNIVERSITY OF HONG KONG ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AnirudhSuram.pdf
# {'index': 'AnirudhSuram.pdf', 'name': ['ANIRUDH REDDY'], 'phone_number': '5087175999', 'email': ['arsuram99@gmail.com'], 'master_degree': {'MS in Data Science : University of Massachusetts Dartmouth', 'MS', 'MACHINE LEARNING: Regression', 'MSE as key metric and achieved RMSE of .976 and .958 being the best in'}, 'bachelor_degree': "Bachelor's In Computer-Science: CVR College of Engineering", 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University\tof\tMassachusetts\tDartmouth', 'bach_school': 'University\tof\tMassachusetts\tDartmouth', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AnnapoornaGopalakrishhna.pdf
# {'index': 'AnnapoornaGopalakrishhna.pdf', 'name': ['ANNAPOORNA M'], 'phone_number': '440-990-8497', 'email': ['annapoornagopalakrishna@gmail.com'], 'master_degree': 'Master of computer science and information systems', 'bachelor_degree': 'Bachelor of Technology', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University — Executive Secretary in Middough company, July 2021 — present ', 'bach_school': 'Institute of technology — Mobile Application Developer, July 2018 — August 2018 ', 'phd_grad_date': None, 'ms_grad_date': '2021 December', 'bach_grad_date': None}
# AnttonWillbanks.pdf
# {'index': 'AnttonWillbanks.pdf', 'name': ['Antton Wilbanks'], 'phone_number': '+1 910.238.0756', 'email': ['wilbanks83@gmail.com'], 'master_degree': 'Master of Science in Data Science', 'bachelor_degree': 'Bachelor of Art in Chemistry', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of North Carolina Wilmington ', 'bach_school': 'University of Oulu (Study Abroad) ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AnyaPatel.pdf
# {'index': 'AnyaPatel.pdf', 'name': ['ANYA PATEL'], 'phone_number': '805 453 1532', 'email': ['anyampatel@gmail.com'], 'master_degree': {'MARY', 'MATLAB', 'MACHINE LEARNING / DATA SCIENCE INTERN'}, 'bachelor_degree': {'B.S.'}, 'phd_degree': set(), 'phd_school': None, 'ms_school': None, 'bach_school': None, 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# ArchitPrem.pdf
# {'index': 'ArchitPrem.pdf', 'name': ['Archit Prem'], 'phone_number': None, 'email': ['archit7@umd.edu'], 'master_degree': 'Master of Science', 'bachelor_degree': 'Bachelor of Technology', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Maryland, Robert H. Smith School of Business ', 'bach_school': 'School of Bus', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# AshviSoni.pdf
# {'index': 'AshviSoni.pdf', 'name': ['Washington DC'], 'phone_number': '+1(202)823-8515', 'email': ['ashvi.y.soni@gmail.com'], 'master_degree': 'Master of Science (M.S.) in Computer Science', 'bachelor_degree': 'Bachelor of Engineering (B.E.) in Computer Engineering', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University', 'bach_school': 'University', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# BaiyuChen.pdf
# {'index': 'BaiyuChen.pdf', 'name': ['BAIYU CHEN'], 'phone_number': '631-305-9842', 'email': ['baiyu@wustl.edu'], 'master_degree': 'Master of Science - Business Analytics', 'bachelor_degree': 'Bachelor of Science - Applied Mathematics and Statistics', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'UNIVERSITY, NY                                                                                                                 Aug 2016 – May 2020 ', 'bach_school': 'UNIVERSITY IN ST. LOUIS, MO                                                                                           Expected Dec 2021 ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# BhavikaChavda.pdf
# {'index': 'BhavikaChavda.pdf', 'name': ['BHAVIKA CHAVDA'], 'phone_number': '(609) 271-1612', 'email': ['bhavika.chavda@gmail.com'], 'master_degree': 'Master of Professional Studies in Data Science', 'bachelor_degree': 'Bachelor of Computer Application', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Maryland, Baltimore County (UMBC), Baltimore, Maryland ', 'bach_school': 'University, Gujarat, India ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# BokyeungKim.pdf
# {'index': 'BokyeungKim.pdf', 'name': ['BOKYEUNG KIM'], 'phone_number': '(443) 379-9308', 'email': ['bokyeung.kim1@gmail.com'], 'master_degree': 'Master of Science in Business Analytics', 'bachelor_degree': 'Bachelor of Science in Business Administration: Marketing', 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Maryland, Robert H. Smith School of Business ', 'bach_school': 'School of Bus', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# BonTrinh.pdf
# {'index': 'BonTrinh.pdf', 'name': ['B O'], 'phone_number': '608-724-2688', 'email': ['bontrinh169@gmail.com'], 'master_degree': set(), 'bachelor_degree': set(), 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of Wisconsin-Madison ', 'bach_school': 'University of Wisconsin-Madison ', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# BukaCakrawala.pdf
# {'index': 'BukaCakrawala.pdf', 'name': ['Buka Cakrawala'], 'phone_number': '2019 - 2020', 'email': ['bcakrawa@ucsd.edu'], 'master_degree': set(), 'bachelor_degree': set(), 'phd_degree': set(), 'phd_school': None, 'ms_school': 'University of California, San Diego — B.S in Mathematics-Computer Science (2017 - June 2021)      ', 'bach_school': 'University of California, San Diego — B.S', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': '2021 June'}
# C01-21111807_Andrew_Decker.pdf
# {'index': 'C01-21111807_Andrew_Decker.pdf', 'name': ['Andrew Decker'], 'phone_number': '(443)-742-3540', 'email': ['eckan01@gettysburg.edu'], 'master_degree': set(), 'bachelor_degree': 'Bachelor of Science in Mathematical Economics Minor Data Science', 'phd_degree': set(), 'phd_school': None, 'ms_school': None, 'bach_school': 'College Bas', 'phd_grad_date': None, 'ms_grad_date': None, 'bach_grad_date': None}
# C01-21120201_Jiayue_Fei.pdf
# None
# CahyariniHariga.pdf
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-3efc97ef5dae> in <module>
#      93 file_path = folder[3]
#      94 for file_path in folder:
# ---> 95     print(parse_resume(file_path))
#
# <ipython-input-14-3efc97ef5dae> in parse_resume(path)
#      82                           'bach_grad_date' : None}
#      83     else:
# ---> 84         info_dict = get_info(raw_txt)
#      85         return_dict = {**{'index': index}, **info_dict}
#      86         return return_dict
#
# <ipython-input-14-3efc97ef5dae> in get_info(txt)
#      13     bach_school = extract_bach_school(txt)
#      14     phd_grad_date = extract_phd_date(txt)
# ---> 15     ms_grad_date = extract_masters_date(txt)
#      16     bach_grad_date = extract_bach_date(txt)
#      17     return {
#
# <ipython-input-13-048d25559b55> in extract_masters_date(txt)
#      31                 if re.findall(year,line):
#      32
# ---> 33                     return(re.findall(year,line)[-1] + ' ' + re.findall(month,line)[-1])
#      34
#      35 def extract_bach_date(txt):
#
# IndexError: list index out of range

# %%
# -------------------- working process ---------------------------------------
def extract_graduation_date(txt1):
    dates=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
    #/^(?=^abc)(?=.*xyz$)(?=.*123)(?=^(?:(?!456).)*$).*$/
    # Working to extract Months :x="(?=("+'|'.join(dates)+r"))"
    x="(?is)education.*?(\d{4})"
    # Working to extract year after education: x="(?is)education.*?(\d{4})"
    if len(re.findall(x,txt1))==0:
        return None
    return max(re.findall(x,txt1))
    ## for dates
    #for dt in dates:
    #    if dt in txt:
    #        return dt


def extract_phd_degree(sentence_txt):
    #https: // abbreviations.yourdictionary.com / articles / degree - abbreviations.html
    degree_list = ["Ph.D.", "M.S.", "MS", "Masters", "Master's", "MA", "M.A.", "MBA", "B.S.E.", "M.S.E.", "Bachelors", "B.tech", "Bachelor's", "Bachelor"]
    degree = {}
    words = nltk.word_tokenize(sentence_txt)
    phd=[]
    for j in range(len(words)):
        if j+2<len(words):
            if "Ph.D." in words[j]:
                phd.append(words[j] +" " + words[j+1] +" " + words[j+2])
    return phd

tagged = nlp(sample_txt) #assumption
degree_list = ["Ph.D.", "M.S.", "MS", "Masters", "Master's", "MA", "M.A.", "MBA", "B.S.E.", "M.S.E.", "Bachelors",
               "B.tech", "Bachelor's", "Bachelor"]
for d in degree_list: print(d)

for word in tagged.ents:
    #print(word.text, word.label_)

        #print(word.text)
        for d in degree_list:
            if d in word.text and word.label_ == "ORG":
                print(word.text)
        #temp_person.append(word.text)
    #return temp_person #return all names

def extract_mast_degree(txt):
    degree_list = ["Ph.D.","M.S.","MS","Masters","Master's","Bachelors","B.tech","Bachelor's","Bachelor"]
    words = nltk.word_tokenize(txt)
    mast=[]
    for j in range(len(words)):
        if j+2<len(words):
            if "M.S." in words[j] or "M.S" in words[j] or "MS" in words[j] or "Masters" in words[j] or "Master's" in words[j]:
                mast.append(words[j] +" " + words[j+1] +" " + words[j+2])
        if j+5<len(words):
            if "Master" in words[j]:
                mast.append(words[j] +" " + words[j+1] +" " + words[j+2] +" " + words[j+3] +" " + words[j+4] + " " + words[j+5])
    return mast

def extract_bach_degree(txt):
    degree_list = ["Ph.D.","M.S.","MS","Masters","Master's","Bachelors","B.tech","Bachelor's","Bachelor"]
    words = nltk.word_tokenize(txt)
    bach=[]
    for j in range(len(words)):
        if j+2<len(words):
            if "Bachelors" in words[j] or "B.tech" in words[j] or "Bachelor's" in words[j] or "B.A." in words[j] or "BS" in words[j] or "B.Sc." in words[j] or "B.S" in words[j]:
                bach.append(words[j] +" " + words[j+1] +" " + words[j+2])
        if j+5<len(words):
            if "Bachelor" in words[j]:
                bach.append(words[j] +" " + words[j+1] +" " + words[j+2] +" " + words[j+3] +" " + words[j+4] + " " + words[j+5])
    return bach

def get_degree_info(sentence_txt, tokens_txt): #-> list of person names
    temp_person = []
    nltk_tagged = pos_tag(tokens_txt[:11])
    for k in range(10):
        if nltk_tagged[k][1] == 'NNP' and nltk_tagged[k + 1][1] == 'NNP':
            nltk_name = nltk_tagged[k][0] + ' ' + nltk_tagged[k + 1][0]
            temp_person.append(nltk_name)
            if len(temp_person) > 0:# stop as long as you got the nltk_name
                return temp_person

        if k > 1:
            if (tokens_txt[k].lower() in indian_last_names) or (tokens_txt[k].lower() in chinese_last_names):
                j = k - 1
                return([tokens_txt[j] + " " + tokens_txt[k]]) #what if kristin (jiating) chen?

    tagged = nlp(sentence_txt[0:200]) #assumption
    for word in tagged.ents:
        if word.label_ == "PERSON":
            temp_person.append(word.text)
        return temp_person #return all names

def extract_master_school(txt):
    masters_set = set()
    p = re.compile(r'(School|University).*(Master|MS|M\.S\.|MA|M\.A\.|MBA|M\.S\.E|M\.tech).*,')
                   #'|((University).*(Master|MS|M\.S\.|MA|M\.A\.|MBA|M\.S\.E|M\.tech).*\\n)')  # greedy
    for m in re.finditer(p, txt):
        print(m.group())
        # candidate_txt = m.group().split(',')[0] #MS Excel MS word....
        # print(candidate_txt)
    #     if 'University' in candidate_txt:
    #         return ' '.join(candidate_txt.split()) #immediate return master
    #     else:
    #         masters_set.add(' '.join(candidate_txt.split()))
    # return masters_set
extract_master_school(sample_txt)
# Out:
# Ph.D.
# M.S.
# MS
# Masters
# Master's
# MA
# M.A.
# MBA
# B.S.E.
# M.S.E.
# Bachelors
# B.tech
# Bachelor's
# Bachelor
# MS PowerPoint
# MS Word

# %%
def get_name(sentence_txt, tokens_txt): #-> list of person names
    temp_person = []
    nltk_tagged = pos_tag(tokens_txt[:11])
    for k in range(10):
        if nltk_tagged[k][1] == 'NNP' and nltk_tagged[k + 1][1] == 'NNP':
            nltk_name = nltk_tagged[k][0] + ' ' + nltk_tagged[k + 1][0]
            temp_person.append(nltk_name)
            if len(temp_person) > 0:# Comment: stop as long as you got the nltk_name
                return temp_person

        # for chunk in doc.noun_chunks:
        #     print(chunk.text) #Comment: maybe try noun chunks to get the name

        if k > 1:
            if (tokens_txt[k].lower() in indian_last_names) or (tokens_txt[k].lower() in chinese_last_names):
                j = k - 1
                return([tokens_txt[j] + " " + tokens_txt[k]]) #Comment: what if kristin (jiating) chen?

    tagged = nlp(sentence_txt[0:200]) #Comment: assume names exist in the top section
    for word in tagged.ents:
        if word.label_ == "PERSON":
            temp_person.append(word.text)
        return temp_person

get_name(sentence_txt=sample_txt, tokens_txt = tokens_txt)

# -----------------------------------------------------------------
RESERVED_WORDS = [
    'school',
    'college',
    'univers',
    'academy',
    'faculty',
    'institute',
    'faculdades',
    'Schola',
    'schule',
    'lise',
    'lyceum',
    'lycee',
    'polytechnic',
    'kolej',
    'ünivers',
    'okul',
    'University'
]

def extract_education(txt): # Comment: this is not solid
    edu=set()
    p = re.compile('(EDUCATION)?\n?(.*?),\s+(.*?),(.*?)')
    for m in re.finditer(p, txt):

        for word in RESERVED_WORDS:
            if word in m.group(2).lower():
                edu.add(m.group(2))
    return edu
extract_education(sample_txt[0:1000])

# -----------------------------
def extract_phone_number(txt):
    PHONE_REG = re.compile(r'[\+\(]?[1-9][0-9 .\-\(\)]{8,}[0-9]')
    phone = re.findall(PHONE_REG, txt)

    if phone:
        number = ''.join(phone[0])

        if txt.find(number) >= 0 and len(number) < 16:
            return number
    return None

# ---------------------------- -
def extract_email(txt):
    EMAIL_REG = re.compile(r'[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+')
    return re.findall(EMAIL_REG, txt)

# -----------------------------------
def extract_phd_degree(txt):
    phd_set = set()
    p = re.compile('(Ph\.D).*,|(Ph\.D).*\\n')
    for m in re.finditer(p, txt):
        candidate_txt = m.group().split(',')[0]
        phd_set.add(' '.join(candidate_txt.split()))
    return phd_set

doc = nlp(sample_txt)
extract_phd_degree(sample_txt)

# ------------------------------------
def extract_master_degree(txt):
    masters_set = set()
    p = re.compile('(Master|MS|M\.S\.|MA|M\.A\.|MBA|M\.S\.E|M\.tech).*,|(Master|MS|M\.S\.|MA|M\.A\.|MBA|M\.S\.E|M\.tech).*\\n')  # greedy
    for m in re.finditer(p, txt):
        candidate_txt = m.group().split(',')[0] #Comment: to avoid getting 'MS Excel MS word'....
        if 'Master' in candidate_txt:
            return ' '.join(candidate_txt.split()) #immediate return master
        else:
            masters_set.add(' '.join(candidate_txt.split()))
    return masters_set

doc = nlp(sample_txt)
extract_master_degree(sample_txt)

# ---------------------------------
def extract_bachelor_degree(txt):
    bachelors_set = set()
    p = re.compile('(Bachelor|BS|B\.S\.|BA|B\.A\.|B\.S\.E|B\.tech).*,|(Bachelor|BS|B\.S\.|BA|B\.A\.|B\.S\.E|B\.tech).*\\n')  # greedy
    for m in re.finditer(p, txt):
        candidate_txt = m.group().split(',')[0] #MS Excel MS word....
        if 'Bachelor' in candidate_txt:
            return ' '.join(candidate_txt.split()) #immediate return master
        else:
            bachelors_set.add(' '.join(candidate_txt.split()))
    return bachelors_set

doc = nlp(sample_txt)
extract_bachelor_degree(sample_txt)

# --------- aggregate -----------------------------
def get_info(txt):
    tokens_txt = preprocess_text(txt)
    name = get_name(txt, tokens_txt)
    education = extract_education(txt)
    phone_number = extract_phone_number(txt)
    email = extract_email(txt)
    master = extract_master_degree(txt)
    bachelor = extract_bachelor_degree(txt)
    phd = extract_phd_degree(txt)
    return {
        'name' : name,
        'phone_number' : phone_number,
        'email' : email,
        'master_degree' : master,
        'bachelor_degree': bachelor,
        'phd_degree' : phd
    }

def parse_resume(path):
    index = os.path.basename(path)
    print(index)
    try:
        raw_txt = read_file(path)
    except pdfminer.pdfparser.PDFSyntaxError:
        return_dict = {'index': index,
                   'name': None,
                   'phone_number': None,
                   'email': None,
                   'master_degree': None,
                   'bachelor_degree': None,
                   'phd_degree': None}
        return return_dict

    if not isinstance(raw_txt, str):
        return_dict = {   'index' : index,
                          'name': None,
                          'phone_number': None,
                          'email': None,
                          'master_degree': None,
                          'bachelor_degree': None,
                          'phd_degree': None}
        return return_dict
    elif len(raw_txt) < 8:
        return_dict = {   'index' : index,
                          'name': None,
                          'phone_number': None,
                          'email': None,
                          'master_degree': None,
                          'bachelor_degree': None,
                          'phd_degree': None}
    else:
        info_dict = get_info(raw_txt)
        return_dict = {**{'index': index}, **info_dict}
        return return_dict

# execution ---------------------
folder = glob.glob(r"./nlp-coe/resume-parser/data/resume_samples/*")

for file_path in folder:
    print(parse_resume(file_path))

# -------------------- working process ---------------------------------------
def extract_graduation_date(txt1):
    dates=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
    #/^(?=^abc)(?=.*xyz$)(?=.*123)(?=^(?:(?!456).)*$).*$/
    # Working to extract Months :x="(?=("+'|'.join(dates)+r"))"
    x="(?is)education.*?(\d{4})"
    # Working to extract year after education: x="(?is)education.*?(\d{4})"
    if len(re.findall(x,txt1))==0:
        return None
    return max(re.findall(x,txt1))
    ## for dates
    #for dt in dates:
    #    if dt in txt:
    #        return dt


def extract_phd_degree(sentence_txt):
    #https: // abbreviations.yourdictionary.com / articles / degree - abbreviations.html
    degree_list = ["Ph.D.", "M.S.", "MS", "Masters", "Master's", "MA", "M.A.", "MBA", "B.S.E.", "M.S.E.", "Bachelors", "B.tech", "Bachelor's", "Bachelor"]
    degree = {}
    words = nltk.word_tokenize(sentence_txt)
    phd=[]
    for j in range(len(words)):
        if j+2<len(words):
            if "Ph.D." in words[j]:
                phd.append(words[j] +" " + words[j+1] +" " + words[j+2])
    return phd

tagged = nlp(sample_txt) #assumption
degree_list = ["Ph.D.", "M.S.", "MS", "Masters", "Master's", "MA", "M.A.", "MBA", "B.S.E.", "M.S.E.", "Bachelors",
               "B.tech", "Bachelor's", "Bachelor"]
for d in degree_list: print(d)

for word in tagged.ents:
    #print(word.text, word.label_)

        #print(word.text)
        for d in degree_list:
            if d in word.text and word.label_ == "ORG":
                print(word.text)
        #temp_person.append(word.text)
    #return temp_person #return all names

def extract_mast_degree(txt):
    degree_list = ["Ph.D.","M.S.","MS","Masters","Master's","Bachelors","B.tech","Bachelor's","Bachelor"]
    words = nltk.word_tokenize(txt)
    mast=[]
    for j in range(len(words)):
        if j+2<len(words):
            if "M.S." in words[j] or "M.S" in words[j] or "MS" in words[j] or "Masters" in words[j] or "Master's" in words[j]:
                mast.append(words[j] +" " + words[j+1] +" " + words[j+2])
        if j+5<len(words):
            if "Master" in words[j]:
                mast.append(words[j] +" " + words[j+1] +" " + words[j+2] +" " + words[j+3] +" " + words[j+4] + " " + words[j+5])
    return mast

def extract_bach_degree(txt):
    degree_list = ["Ph.D.","M.S.","MS","Masters","Master's","Bachelors","B.tech","Bachelor's","Bachelor"]
    words = nltk.word_tokenize(txt)
    bach=[]
    for j in range(len(words)):
        if j+2<len(words):
            if "Bachelors" in words[j] or "B.tech" in words[j] or "Bachelor's" in words[j] or "B.A." in words[j] or "BS" in words[j] or "B.Sc." in words[j] or "B.S" in words[j]:
                bach.append(words[j] +" " + words[j+1] +" " + words[j+2])
        if j+5<len(words):
            if "Bachelor" in words[j]:
                bach.append(words[j] +" " + words[j+1] +" " + words[j+2] +" " + words[j+3] +" " + words[j+4] + " " + words[j+5])
    return bach

def get_degree_info(sentence_txt, tokens_txt): #-> list of person names
    temp_person = []
    nltk_tagged = pos_tag(tokens_txt[:11])
    for k in range(10):
        if nltk_tagged[k][1] == 'NNP' and nltk_tagged[k + 1][1] == 'NNP':
            nltk_name = nltk_tagged[k][0] + ' ' + nltk_tagged[k + 1][0]
            temp_person.append(nltk_name)
            if len(temp_person) > 0:# stop as long as you got the nltk_name
                return temp_person

        if k > 1:
            if (tokens_txt[k].lower() in indian_last_names) or (tokens_txt[k].lower() in chinese_last_names):
                j = k - 1
                return([tokens_txt[j] + " " + tokens_txt[k]]) #what if kristin (jiating) chen?

    tagged = nlp(sentence_txt[0:200]) #assumption
    for word in tagged.ents:
        if word.label_ == "PERSON":
            temp_person.append(word.text)
        return temp_person #return all names

def extract_master_school(txt):
    masters_set = set()
    p = re.compile(r'(School|University).*(Master|MS|M\.S\.|MA|M\.A\.|MBA|M\.S\.E|M\.tech).*,')
                   #'|((University).*(Master|MS|M\.S\.|MA|M\.A\.|MBA|M\.S\.E|M\.tech).*\\n)')  # greedy
    for m in re.finditer(p, txt):
        print(m.group())
        # candidate_txt = m.group().split(',')[0] #MS Excel MS word....
        # print(candidate_txt)
    #     if 'University' in candidate_txt:
    #         return ' '.join(candidate_txt.split()) #immediate return master
    #     else:
    #         masters_set.add(' '.join(candidate_txt.split()))
    # return masters_set
extract_master_school(sample_txt)
# Out:
# Ph.D.
# M.S.
# MS
# Masters
# Master's
# MA
# M.A.
# MBA
# B.S.E.
# M.S.E.
# Bachelors
# B.tech
# Bachelor's
# Bachelor
# MS PowerPoint
# MS Word
